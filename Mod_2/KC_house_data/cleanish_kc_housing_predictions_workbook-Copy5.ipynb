# %%
import itertools
import numpy as np
import pandas as pd 
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('ticks')

import pickle

from sklearn import metrics
from sklearn.metrics import mean_squared_error, roc_curve, roc_auc_score, accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
df = pd.read_csv('kc_house_data_train.csv', index_col=0)
df_test_features = pd.read_csv('kc_house_data_test_features.csv', index_col=0)

# %%
df_untouched = pd.read_csv('kc_house_data_train.csv', index_col=0)

# %%
df.head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  2591820310  20141006T000000   365000.0         4       2.25         2070
# 1  7974200820  20140821T000000   865000.0         5       3.00         2900
# 2  7701450110  20140815T000000  1038000.0         4       2.50         3770
# 3  9522300010  20150331T000000  1490000.0         3       3.50         4560
# 4  9510861140  20140714T000000   711000.0         3       2.50         2550
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      8893     2.0           0     0  ...      8        2070              0
# 1      6730     1.0           0     0  ...      8        1830           1070
# 2     10893     2.0           0     2  ...     11        3770              0
# 3     14608     2.0           0     2  ...     12        4560              0
# 4      5376     2.0           0     0  ...      9        2550              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1986             0    98058  47.4388 -122.162           2390
# 1      1977             0    98115  47.6784 -122.285           2370
# 2      1997             0    98006  47.5646 -122.129           3710
# 3      1990             0    98034  47.6995 -122.228           4050
# 4      2004             0    98052  47.6647 -122.083           2250
#
#    sqft_lot15
# 0        7700
# 1        6283
# 2        9685
# 3       14226
# 4        4050
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (17290, 21)

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  1.729000e+04  1.729000e+04  17290.000000  17290.000000  17290.000000
# mean   4.565502e+09  5.407395e+05      3.372470      2.111943   2081.464604
# std    2.874656e+09  3.733190e+05      0.939346      0.770476    920.018539
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.114701e+09  3.210000e+05      3.000000      1.500000   1430.000000
# 50%    3.903650e+09  4.500000e+05      3.000000      2.250000   1920.000000
# 75%    7.301150e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  1.729000e+04  17290.000000  17290.000000  17290.000000  17290.000000
# mean   1.524340e+04      1.490312      0.007981      0.238519      3.408502
# std    4.230462e+04      0.538909      0.088985      0.775229      0.651296
# min    5.720000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.081250e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.642000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.072575e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  17290.000000  17290.000000   17290.000000  17290.000000  17290.000000
# mean       7.654425   1789.306015     292.158589   1970.792019     83.806304
# std        1.174718    829.265107     443.151874     29.343516    400.329376
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1200.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1974.000000      0.000000
# 75%        8.000000   2214.500000     560.000000   1996.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  17290.000000  17290.000000  17290.000000   17290.000000   17290.000000
# mean   98078.193175     47.560058   -122.214258    1987.986698   12873.475824
# std       53.607949      0.138412      0.140857     684.802635   27227.437583
# min    98001.000000     47.155900   -122.519000     399.000000     659.000000
# 25%    98033.000000     47.471200   -122.329000    1490.000000    5111.250000
# 50%    98065.000000     47.571600   -122.230000    1840.000000    7622.500000
# 75%    98118.000000     47.677900   -122.126000    2360.000000   10101.750000
# max    98199.000000     47.777600   -121.315000    6210.000000  858132.000000

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
def find_extremas(df):
    extrema_list = []
    for column in list(df.columns):
        if df[column]['max'] > ( df[column]['mean']+5*df[column]['std']):
            extrema_list.append(column)
    return extrema_list

descriptor = df.describe()
extreme_cols = find_extremas(descriptor)
extreme_cols
# Out:
# ['price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'waterfront',
#  'sqft_above',
#  'sqft_basement',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
def extreme(df,columns):
    for column in columns:
        mean = df[column].mean()
        std = df[column].std()
        conditions = [
            df[column] > mean + 4*std
        ]
        df[column] = np.where(df[column] > mean + 5*std, mean + 5*std, df[column])

# %%
extreme(df, ['sqft_living',
 'sqft_lot', 'sqft_above',
 'sqft_basement', 'sqft_living15',
 'sqft_lot15'])

# %%
sns.set_style('ticks')
df.hist('price', bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c4ef9b0>]],
#       dtype=object)

# %%
df['log_price'] = df['price'].apply(lambda x: np.log(x))
df.hist('log_price', bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12d7a8ef0>]],
#       dtype=object)

# %%
target = df['log_price']
features = df.drop(['log_price'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(features, target, random_state=22, test_size=0.2)

# %%
df.boxplot('log_price', 'condition')

# %%
df.boxplot('log_price', 'view')

# %%
df.boxplot('log_price', 'waterfront')

# %%
df['waterfront_view'] = df['waterfront'] * df['view']
df.boxplot('log_price', 'waterfront_view')

# %%
df['waterfront_cond'] = df['waterfront'] * df['condition']
df.boxplot('log_price', 'waterfront_cond')

# %%
df['waterfront_grade'] = df['waterfront'] * df['grade']
df.boxplot('log_price', 'waterfront_grade')

# %%
df['view_grade'] = df['view'] + df['grade']
df.boxplot('log_price', 'view_grade')

# %%
df.boxplot('log_price', 'bedrooms')

# %%
df['bedrooms'].value_counts()
# Out:
# 3     7864
# 4     5488
# 2     2204
# 5     1283
# 6      229
# 1      160
# 7       30
# 0       12
# 8       10
# 9        5
# 10       3
# 11       1
# 33       1
# Name: bedrooms, dtype: int64

# %%
conditions = [df['bedrooms'] == 0, df['bedrooms'] > 7]
choices = [1, 7]

df['bedrooms'] = np.select(conditions, choices, df['bedrooms'])

# %%
df['bedrooms'].value_counts()
# Out:
# 3    7864
# 4    5488
# 2    2204
# 5    1283
# 6     229
# 1     172
# 7      50
# Name: bedrooms, dtype: int64

# %%
df.boxplot('log_price', 'bedrooms')

# %%
df.boxplot('log_price', 'bathrooms')

# %%
df['bathrooms'].unique()
# Out:
# array([2.25, 3.  , 2.5 , 3.5 , 2.  , 1.  , 1.75, 3.75, 3.25, 4.25, 2.75,
#        1.5 , 4.5 , 4.  , 4.75, 0.75, 0.  , 5.  , 5.5 , 6.  , 1.25, 5.75,
#        6.75, 5.25, 6.5 , 8.  , 7.5 , 6.25, 0.5 , 7.75])

# %%
conditions = [df['bathrooms'] <= 1, df['bathrooms'] <= 1.75,
              df['bathrooms'] <= 2, df['bathrooms'] <= 2.75,
              df['bathrooms'] <= 3, df['bathrooms'] <= 3.75,
              df['bathrooms'] <= 4, df['bathrooms'] <= 4.75]
choices = [1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5]

df['bathrooms'] = np.select(conditions, choices, 5)

# %%
df['bathrooms'].value_counts()
# Out:
# 2.5    6884
# 1.5    3605
# 1.0    3163
# 2.0    1549
# 3.5    1181
# 3.0     592
# 4.5     156
# 4.0     107
# 5.0      53
# Name: bathrooms, dtype: int64

# %%
df.boxplot('log_price', 'bathrooms')

# %%
df['bed_bath_ratio'] = df['bedrooms'] / df['bathrooms']
df.boxplot('log_price', 'bed_bath_ratio')

# %%
df['living_bed_ratio'] = df['sqft_living'] / df['bedrooms']

# %%
df['living_bed_ratio'] = np.where(df['living_bed_ratio'] == np.inf,
                                  df['living_bed_ratio'].min(), df['living_bed_ratio'])

# %%
df['log_living_bed_ratio'] = df['living_bed_ratio'].apply(lambda x: np.log(x))

# %%
sns.regplot(df['log_living_bed_ratio'], df['log_price'])

# %%
df['log_sqft_lot'] = df['sqft_lot'].apply(lambda x: np.log(x))
df.plot.scatter('log_sqft_lot', 'log_price')

# %%
df['sqft_yard'] = df['sqft_lot'] - (df['sqft_living'] / df['floors'])
df['sqft_yard'] = np.where(df['sqft_yard'] < 0, df['sqft_yard'].median(), df['sqft_yard'])
df['sqft_yard'].min(), df['sqft_yard'].max()
# Out:
# (21.66666666666663, 226233.18549236885)

# %%
df['log_sqft_yard'] = df['sqft_yard'].apply(lambda x: np.log(x))
df.plot.scatter('log_sqft_yard', 'log_price')

# %%
df['log_sqft_living'] = df['sqft_living'].apply(lambda x: np.log(x))
df.hist('log_sqft_living')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12f8b06a0>]],
#       dtype=object)

# %%
sns.regplot(df['log_sqft_living'], df['log_price'])

# %%
f = 'log_price~log_sqft_living+log_sqft_yard'
model = ols(formula=f, data=df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.464
# Model:                            OLS   Adj. R-squared:                  0.464
# Method:                 Least Squares   F-statistic:                     7488.
# Date:                Mon, 04 May 2020   Prob (F-statistic):               0.00
# Time:                        09:55:32   Log-Likelihood:                -8059.2
# No. Observations:               17290   AIC:                         1.612e+04
# Df Residuals:                   17287   BIC:                         1.615e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.8669      0.054    128.185      0.000       6.762       6.972
# log_sqft_living     0.8730      0.007    121.055      0.000       0.859       0.887
# log_sqft_yard      -0.0470      0.003    -15.923      0.000      -0.053      -0.041
# ==============================================================================
# Omnibus:                       81.897   Durbin-Watson:                   2.013
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.888
# Skew:                           0.167   Prob(JB):                     1.00e-18
# Kurtosis:                       2.945   Cond. No.                         214.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
df['yr_built_reno'] = np.where(df['yr_renovated'] == 0, df['yr_built'], df['yr_renovated'])
df['yr_built_reno'].describe()
# Out:
# count    17290.000000
# mean      1973.158010
# std         28.805976
# min       1900.000000
# 25%       1954.000000
# 50%       1977.000000
# 75%       1999.000000
# max       2015.000000
# Name: yr_built_reno, dtype: float64

# %%
df.plot.scatter('yr_built_reno', 'log_price')

# %%
df['since_built_reno'] = df['yr_built_reno'].apply(lambda x: 2015 - x)
df.plot.scatter('since_built_reno', 'log_price')

# %%
df.boxplot('log_price', 'floors')

# %%
df['log_sqft_living15'] = df['sqft_living15'].apply(lambda x: np.log(x))
df.plot.scatter('log_sqft_living15', 'log_price')

# %%
df['log_sqft_basement'] = df['sqft_basement'].apply(lambda x: np.log(x))
df.plot.scatter('log_sqft_basement', 'log_price')

# %%
df.plot.scatter('sqft_basement', 'log_price')

# %%
df['has_basement'] = np.where(df['sqft_basement'] == 0, 0, 1)
df.boxplot('log_price', 'has_basement')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'log_price',
#        'waterfront_view', 'waterfront_cond', 'waterfront_grade', 'view_grade',
#        'bed_bath_ratio', 'living_bed_ratio', 'log_living_bed_ratio',
#        'log_sqft_lot', 'sqft_yard', 'log_sqft_yard', 'log_sqft_living',
#        'yr_built_reno', 'since_built_reno', 'log_sqft_living15',
#        'log_sqft_basement', 'has_basement'],
#       dtype='object')

# %%
columns = ['view', 'condition', 'grade', 'zipcode', 'view_grade']
df = pd.get_dummies(data=df, columns=columns, prefix=columns, drop_first=True)
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'sqft_above',
#        ...
#        'view_grade_8', 'view_grade_9', 'view_grade_10', 'view_grade_11',
#        'view_grade_12', 'view_grade_13', 'view_grade_14', 'view_grade_15',
#        'view_grade_16', 'view_grade_17'],
#       dtype='object', length=136)

# %%
floor_dict = {
            'floors_1.5': 'floors_1_half',
            'floors_2.0': 'floors_2',
            'floors_2.5': 'floors_2_half',
            'floors_3.0': 'floors_3',
            'floors_3.5': 'floors_3_half'
}

df = df.rename(columns=floor_dict)

# %%
print(df.columns)
# Out:
# Index(['id', 'date', 'price', 'sqft_living', 'sqft_lot', 'waterfront',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        ...
#        'view_grade_8', 'view_grade_9', 'view_grade_10', 'view_grade_11',
#        'view_grade_12', 'view_grade_13', 'view_grade_14', 'view_grade_15',
#        'view_grade_16', 'view_grade_17'],
#       dtype='object', length=152)

# %%
bath_dict = {
            'bathrooms_1.0': 'bathrooms_1',
            'bathrooms_1.5': 'bathrooms_1_half',
            'bathrooms_2.0': 'bathrooms_2',
            'bathrooms_2.5': 'bathrooms_2_half',
            'bathrooms_3.0': 'bathrooms_3',
            'bathrooms_3.5': 'bathrooms_3_half',
            'bathrooms_4.0': 'bathrooms_4',
            'bathrooms_4.5': 'bathrooms_4_half',
            'bathrooms_5.0': 'bathrooms_5'
}

df = df.rename(columns=bath_dict)

# %%
df.shape
# Out:
# (17290, 152)

# %%
df_untouched.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
untouched_cats = '+'.join(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront',
                           'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built',
                           'yr_renovated', 'sqft_living15', 'sqft_lot15'])

# %%
f_untouched = 'price~' + untouched_cats
model_untouched = ols(formula=f_untouched, data=df_untouched).fit()
model_untouched.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.654
# Model:                            OLS   Adj. R-squared:                  0.653
# Method:                 Least Squares   F-statistic:                     2328.
# Date:                Sun, 03 May 2020   Prob (F-statistic):               0.00
# Time:                        23:37:16   Log-Likelihood:            -2.3720e+05
# No. Observations:               17290   AIC:                         4.744e+05
# Df Residuals:                   17275   BIC:                         4.746e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      6.239e+06   1.57e+05     39.635      0.000    5.93e+06    6.55e+06
# bedrooms      -3.877e+04   2263.064    -17.133      0.000   -4.32e+04   -3.43e+04
# bathrooms      4.534e+04   3963.126     11.440      0.000    3.76e+04    5.31e+04
# sqft_living     112.0537      2.755     40.674      0.000     106.654     117.454
# sqft_lot         -0.0143      0.056     -0.257      0.797      -0.124       0.095
# floors         2.525e+04   4302.548      5.868      0.000    1.68e+04    3.37e+04
# waterfront     5.911e+05   2.07e+04     28.581      0.000    5.51e+05    6.32e+05
# view           4.291e+04   2559.474     16.765      0.000    3.79e+04    4.79e+04
# condition      2.001e+04   2831.563      7.066      0.000    1.45e+04    2.56e+04
# grade          1.197e+05   2564.254     46.667      0.000    1.15e+05    1.25e+05
# sqft_above       53.4308      2.691     19.858      0.000      48.157      58.705
# sqft_basement    58.6229      3.158     18.563      0.000      52.433      64.813
# yr_built      -3598.3856     80.746    -44.564      0.000   -3756.655   -3440.116
# yr_renovated      7.7960      4.459      1.748      0.080      -0.944      16.536
# sqft_living15    25.9149      4.100      6.321      0.000      17.879      33.951
# sqft_lot15       -0.5011      0.087     -5.735      0.000      -0.672      -0.330
# ==============================================================================
# Omnibus:                    13715.606   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1138040.667
# Skew:                           3.235   Prob(JB):                         0.00
# Kurtosis:                      42.215   Cond. No.                     1.68e+17
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.6e-21. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'sqft_living', 'sqft_lot', 'waterfront',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated',
#        ...
#        'view_grade_8', 'view_grade_9', 'view_grade_10', 'view_grade_11',
#        'view_grade_12', 'view_grade_13', 'view_grade_14', 'view_grade_15',
#        'view_grade_16', 'view_grade_17'],
#       dtype='object', length=152)

# %% [markdown]
# # FEATURES CREATION

# %%
features = df.drop(['id', 'date', 'price', 'log_sqft_living', 'log_sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built',
                    'yr_renovated', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'log_living_bed_ratio',
                    'bed_bath_ratio', 'log_sqft_lot', 'log_sqft_yard', 'yr_built_reno', 'log_sqft_living15',
                    'log_sqft_basement',
                    'waterfront_view', 'waterfront_cond', 'waterfront_grade',
#                     'log_living_bed_ratio',
#                     'view_grade',
#                     'since_built_reno'                    
                   ], 
                    axis = 1)

# %%
features.columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'log_price', 'living_bed_ratio', 'sqft_yard',
#        'since_built_reno',
#        ...
#        'view_grade_8', 'view_grade_9', 'view_grade_10', 'view_grade_11',
#        'view_grade_12', 'view_grade_13', 'view_grade_14', 'view_grade_15',
#        'view_grade_16', 'view_grade_17'],
#       dtype='object', length=114)

# %%
features_list = list(features.columns)
features_list.remove('log_price')
f_list = '+'.join(features_list)

# %%
f = 'log_price~' + f_list
model = ols(formula=f, data=features).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.876
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     1102.
# Date:                Mon, 04 May 2020   Prob (F-statistic):               0.00
# Time:                        10:12:40   Log-Likelihood:                 4585.7
# No. Observations:               17290   AIC:                            -8949.
# Df Residuals:                   17179   BIC:                            -8088.
# Df Model:                         110
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           11.3239      0.188     60.107      0.000      10.955      11.693
# bedrooms             0.0387      0.004      8.705      0.000       0.030       0.047
# bathrooms            0.0315      0.003      9.615      0.000       0.025       0.038
# sqft_living          0.0002   7.74e-06     25.329      0.000       0.000       0.000
# sqft_lot         -4.954e-05   6.42e-06     -7.711      0.000   -6.21e-05   -3.69e-05
# floors              -0.0761      0.007    -10.955      0.000      -0.090      -0.062
# waterfront           0.4595      0.020     22.445      0.000       0.419       0.500
# living_bed_ratio     0.0002   2.11e-05     10.307      0.000       0.000       0.000
# sqft_yard         5.069e-05   6.43e-06      7.888      0.000    3.81e-05    6.33e-05
# since_built_reno     0.0002    8.3e-05      2.091      0.037    1.09e-05       0.000
# has_basement        -0.0355      0.004     -9.316      0.000      -0.043      -0.028
# view_1               0.1076      0.015      7.356      0.000       0.079       0.136
# view_2               0.0845      0.019      4.539      0.000       0.048       0.121
# view_3               0.1478      0.027      5.399      0.000       0.094       0.201
# view_4               0.2759      0.036      7.621      0.000       0.205       0.347
# condition_2          0.1482      0.042      3.499      0.000       0.065       0.231
# condition_3          0.2664      0.040      6.739      0.000       0.189       0.344
# condition_4          0.3083      0.040      7.798      0.000       0.231       0.386
# condition_5          0.3723      0.040      9.363      0.000       0.294       0.450
# grade_3             -0.0376      0.117     -0.322      0.747      -0.266       0.191
# grade_4              0.1335      0.125      1.064      0.287      -0.112       0.379
# grade_5             -0.0667      0.096     -0.695      0.487      -0.255       0.121
# grade_6              0.0574      0.096      0.596      0.551      -0.131       0.246
# grade_7              0.1178      0.100      1.181      0.237      -0.078       0.313
# grade_8              0.2191      0.105      2.096      0.036       0.014       0.424
# grade_9              0.2991      0.110      2.722      0.007       0.084       0.514
# grade_10             0.3697      0.116      3.195      0.001       0.143       0.596
# grade_11             0.4134      0.122      3.391      0.001       0.174       0.652
# grade_12             0.4862      0.130      3.751      0.000       0.232       0.740
# grade_13             0.7712      0.144      5.337      0.000       0.488       1.054
# zipcode_98002       -0.0405      0.019     -2.177      0.029      -0.077      -0.004
# zipcode_98003       -0.0024      0.017     -0.141      0.888      -0.035       0.030
# zipcode_98004        1.1286      0.017     67.764      0.000       1.096       1.161
# zipcode_98005        0.7342      0.019     37.713      0.000       0.696       0.772
# zipcode_98006        0.6457      0.015     43.567      0.000       0.617       0.675
# zipcode_98007        0.6439      0.020     31.792      0.000       0.604       0.684
# zipcode_98008        0.6417      0.017     38.410      0.000       0.609       0.674
# zipcode_98010        0.2316      0.024      9.487      0.000       0.184       0.279
# zipcode_98011        0.4569      0.018     24.914      0.000       0.421       0.493
# zipcode_98014        0.2715      0.022     12.420      0.000       0.229       0.314
# zipcode_98019        0.3215      0.019     16.840      0.000       0.284       0.359
# zipcode_98022        0.0273      0.018      1.539      0.124      -0.007       0.062
# zipcode_98023       -0.0288      0.014     -1.994      0.046      -0.057      -0.000
# zipcode_98024        0.4072      0.026     15.557      0.000       0.356       0.458
# zipcode_98027        0.5027      0.015     33.128      0.000       0.473       0.532
# zipcode_98028        0.4204      0.017     25.047      0.000       0.388       0.453
# zipcode_98029        0.5872      0.016     35.969      0.000       0.555       0.619
# zipcode_98030        0.0474      0.017      2.761      0.006       0.014       0.081
# zipcode_98031        0.0690      0.017      4.093      0.000       0.036       0.102
# zipcode_98032       -0.0322      0.021     -1.501      0.133      -0.074       0.010
# zipcode_98033        0.7699      0.015     51.623      0.000       0.741       0.799
# zipcode_98034        0.5296      0.014     37.170      0.000       0.502       0.557
# zipcode_98038        0.1668      0.014     11.789      0.000       0.139       0.195
# zipcode_98039        1.2785      0.031     40.811      0.000       1.217       1.340
# zipcode_98040        0.8806      0.017     52.108      0.000       0.847       0.914
# zipcode_98042        0.0618      0.014      4.319      0.000       0.034       0.090
# zipcode_98045        0.3075      0.018     17.130      0.000       0.272       0.343
# zipcode_98052        0.6379      0.014     45.309      0.000       0.610       0.666
# zipcode_98053        0.5768      0.015     37.616      0.000       0.547       0.607
# zipcode_98055        0.1366      0.017      8.042      0.000       0.103       0.170
# zipcode_98056        0.3059      0.015     20.284      0.000       0.276       0.336
# zipcode_98058        0.1650      0.015     11.310      0.000       0.136       0.194
# zipcode_98059        0.3450      0.015     23.406      0.000       0.316       0.374
# zipcode_98065        0.4128      0.016     25.340      0.000       0.381       0.445
# zipcode_98070        0.2952      0.022     13.155      0.000       0.251       0.339
# zipcode_98072        0.4919      0.017     29.089      0.000       0.459       0.525
# zipcode_98074        0.5595      0.015     37.305      0.000       0.530       0.589
# zipcode_98075        0.5777      0.016     36.390      0.000       0.547       0.609
# zipcode_98077        0.4416      0.019     23.727      0.000       0.405       0.478
# zipcode_98092        0.0217      0.016      1.382      0.167      -0.009       0.052
# zipcode_98102        0.9281      0.024     38.417      0.000       0.881       0.975
# zipcode_98103        0.8028      0.015     55.269      0.000       0.774       0.831
# zipcode_98105        0.9293      0.018     50.279      0.000       0.893       0.965
# zipcode_98106        0.2976      0.016     18.532      0.000       0.266       0.329
# zipcode_98107        0.8136      0.017     47.059      0.000       0.780       0.848
# zipcode_98108        0.3347      0.019     17.703      0.000       0.298       0.372
# zipcode_98109        0.9545      0.023     40.720      0.000       0.909       1.000
# zipcode_98112        1.0319      0.017     59.370      0.000       0.998       1.066
# zipcode_98115        0.7895      0.014     55.089      0.000       0.761       0.818
# zipcode_98116        0.7344      0.016     45.309      0.000       0.703       0.766
# zipcode_98117        0.7819      0.015     53.828      0.000       0.753       0.810
# zipcode_98118        0.4418      0.015     30.199      0.000       0.413       0.470
# zipcode_98119        0.9696      0.019     50.138      0.000       0.932       1.007
# zipcode_98122        0.7793      0.017     46.273      0.000       0.746       0.812
# zipcode_98125        0.5417      0.015     35.421      0.000       0.512       0.572
# zipcode_98126        0.5060      0.016     31.708      0.000       0.475       0.537
# zipcode_98133        0.4368      0.015     30.011      0.000       0.408       0.465
# zipcode_98136        0.6636      0.017     38.700      0.000       0.630       0.697
# zipcode_98144        0.6500      0.016     40.240      0.000       0.618       0.682
# zipcode_98146        0.2585      0.016     15.808      0.000       0.226       0.291
# zipcode_98148        0.1227      0.031      4.019      0.000       0.063       0.183
# zipcode_98155        0.4148      0.015     27.760      0.000       0.386       0.444
# zipcode_98166        0.3006      0.017     17.552      0.000       0.267       0.334
# zipcode_98168        0.0614      0.017      3.608      0.000       0.028       0.095
# zipcode_98177        0.5940      0.017     34.946      0.000       0.561       0.627
# zipcode_98178        0.1255      0.017      7.370      0.000       0.092       0.159
# zipcode_98188        0.0806      0.021      3.834      0.000       0.039       0.122
# zipcode_98198        0.0466      0.017      2.768      0.006       0.014       0.080
# zipcode_98199        0.8368      0.016     51.460      0.000       0.805       0.869
# view_grade_3        -0.0376      0.117     -0.322      0.747      -0.266       0.191
# view_grade_4        -0.0934      0.156     -0.599      0.549      -0.399       0.212
# view_grade_5         0.1610      0.121      1.334      0.182      -0.076       0.398
# view_grade_6         0.1471      0.108      1.362      0.173      -0.065       0.359
# view_grade_7         0.2112      0.100      2.109      0.035       0.015       0.407
# view_grade_8         0.2238      0.093      2.406      0.016       0.041       0.406
# view_grade_9         0.2670      0.086      3.094      0.002       0.098       0.436
# view_grade_10        0.2578      0.080      3.225      0.001       0.101       0.414
# view_grade_11        0.2853      0.074      3.857      0.000       0.140       0.430
# view_grade_12        0.2632      0.069      3.840      0.000       0.129       0.397
# view_grade_13        0.2714      0.064      4.245      0.000       0.146       0.397
# view_grade_14        0.3100      0.061      5.100      0.000       0.191       0.429
# view_grade_15        0.1420      0.061      2.347      0.019       0.023       0.261
# view_grade_16        0.1404      0.063      2.217      0.027       0.016       0.264
# view_grade_17        0.2139      0.108      1.974      0.048       0.002       0.426
# ==============================================================================
# Omnibus:                     1280.326   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5224.191
# Skew:                          -0.270   Prob(JB):                         0.00
# Kurtosis:                       5.638   Cond. No.                     5.72e+20
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.05e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# # TRAIN-TEST SPLIT!!!

# %%
target = features['log_price']
features_only = features.drop(['log_price'], axis=1)
X_train, X_test, y_train, y_test = train_test_split(features_only, target, random_state=22, test_size=0.2)
# random_state=22,

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train =pd.DataFrame(data=scaler.transform(X_train), columns=features_list)
X_test =pd.DataFrame(data=scaler.transform(X_test), columns=features_list)

# %%
final_scaler = StandardScaler()
final_scaler = final_scaler.fit(features_only)

# %%
import pickle
# Save
with open('final_scaler.pickle', 'wb') as f:
    pickle.dump(final_scaler, f)

# %% [markdown]
# ## "Standard" model

# %%
#instantiate a linear regression object
lm = LinearRegression()

#fit the linear regression to the data
lm = lm.fit(X_train, y_train)

y_train_pred = np.exp(lm.predict(X_train))

train_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))


print('Training Root Mean Squared Error:' , train_rmse)

y_pred = np.exp(lm.predict(X_test))

test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred))

print('Testing Root Mean Squared Error:' , test_rmse)


print('Training: ', train_rmse, "vs. Testing: ", test_rmse)
# Out:
# Training Root Mean Squared Error: 636254.9629845442
# Testing Root Mean Squared Error: 643853.9069575599
# Training:  636254.9629845442 vs. Testing:  643853.9069575599

# %%
standard_regression = LinearRegression()
standard_regression = standard_regression.fit(features_only, target)

# %%
with open('standard_regression_model.pickle', 'wb') as f:
    pickle.dump(standard_regression, f)

# %% [markdown]
# ## F-Test

# %%
from sklearn.feature_selection import SelectKBest, f_regression,mutual_info_regression

selector = SelectKBest(f_regression, k=9)

selector.fit(X_train, y_train)

selected_columns = X_train.columns[selector.get_support()]
removed_columns = X_train.columns[~selector.get_support()]
# X_train = X_train[selected_columns]
# X_test = X_test[selected_columns]

# %%
k_selector = SelectKBest(f_regression, k=9)
k_selector.fit(features_only, target)
# Out:
# SelectKBest(k=9, score_func=<function f_regression at 0x126fce730>)

# %%
with open('k_selector.pickle', 'wb') as f:
    pickle.dump(k_selector, f)

# %%
selected_columns_full = features_only.columns[k_selector.get_support()]
selected_columns_full
# Out:
# Index(['log_living_bed_ratio', 'log_sqft_living', 'bathrooms_3_half',
#        'grade_6', 'grade_7', 'grade_9', 'grade_10', 'view_grade_6',
#        'view_grade_7'],
#       dtype='object')

# %%
selected_columns
# Out:
# Index(['bedrooms', 'bathrooms', 'sqft_living', 'living_bed_ratio', 'grade_7',
#        'grade_9', 'grade_10', 'view_grade_6', 'view_grade_7'],
#       dtype='object')

# %%
#instantiate a linear regression object
lm_kbest = LinearRegression()

#fit the linear regression to the data
lm_kbest = lm_kbest.fit(X_train[selected_columns], y_train)

y_train_kbest = np.exp(lm_kbest.predict(X_train[selected_columns]))


trainK_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_train_kbest))


print('Training Root Mean Squared Error:' , trainK_rmse)

y_kbest = np.exp(lm_kbest.predict(X_test[selected_columns]))

testK_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_kbest))

print('Testing Root Mean Squared Error:' , testK_rmse)


print('Original: ', test_rmse, "vs. KBest: ", testK_rmse)
# Out:
# Training Root Mean Squared Error: 557875.812617323
# Testing Root Mean Squared Error: 560842.333041508
# Original:  643853.9069575599 vs. KBest:  560842.333041508

# %%
kbest_regression = LinearRegression()
kbest_regression = kbest_regression.fit(features_only[selected_columns_full], target)

# %%
with open('kbest_regression.pickle', 'wb') as f:
    pickle.dump(kbest_regression, f)

# %%
f_list_selected = '+'.join(features[selected_columns].columns)
f_selected = 'log_price~' + f_list_selected
model_selected = ols(formula=f_selected, data=features).fit()
model_selected.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              log_price   R-squared:                       0.547
# Model:                            OLS   Adj. R-squared:                  0.546
# Method:                 Least Squares   F-statistic:                     1737.
# Date:                Sun, 03 May 2020   Prob (F-statistic):               0.00
# Time:                        23:10:57   Log-Likelihood:                -6612.7
# No. Observations:               17290   AIC:                         1.325e+04
# Df Residuals:                   17277   BIC:                         1.335e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# Intercept                8.5164      0.078    109.825      0.000       8.364       8.668
# log_living_bed_ratio     0.1668      0.013     13.082      0.000       0.142       0.192
# log_sqft_living          0.4695      0.011     43.075      0.000       0.448       0.491
# bathrooms_3_half         0.1157      0.012      9.898      0.000       0.093       0.139
# floors_2                -0.1124      0.006    -17.390      0.000      -0.125      -0.100
# grade_6                 -0.0237      0.044     -0.539      0.590      -0.110       0.063
# grade_7                  0.0097      0.019      0.501      0.616      -0.028       0.048
# grade_9                  0.2059      0.010     21.197      0.000       0.187       0.225
# grade_10                 0.3798      0.018     21.662      0.000       0.345       0.414
# grade_11                 0.5685      0.022     25.934      0.000       0.525       0.611
# view_grade_6            -0.2735      0.044     -6.164      0.000      -0.360      -0.187
# view_grade_7            -0.1875      0.019     -9.776      0.000      -0.225      -0.150
# view_grade_10            0.0049      0.015      0.316      0.752      -0.025       0.035
# ==============================================================================
# Omnibus:                       92.256   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               99.880
# Skew:                           0.146   Prob(JB):                     2.05e-22
# Kurtosis:                       3.230   Cond. No.                         290.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Recursive Feature Elimination

# %%
from sklearn import linear_model
from sklearn.feature_selection import RFECV

rfe = linear_model.LinearRegression()
# Create recursive feature eliminator that scores features by mean squared errors
selector = RFECV(estimator=rfe, step=1, cv=10, scoring='neg_mean_squared_error')
# Fit recursive feature eliminator 
selector.fit(X_train, y_train)

selected_rfe = X_train.columns[selector.support_]
removed_rfe = X_train.columns[~selector.support_]

# %%
selected_rfe
# Out:
# Index(['log_living_bed_ratio', 'log_sqft_living', 'bedrooms_3', 'bedrooms_4',
#        'view_1', 'view_2', 'view_3', 'view_4', 'condition_3', 'condition_4',
#        'condition_5', 'grade_8', 'grade_9', 'grade_10', 'grade_11', 'grade_12',
#        'grade_13', 'zipcode_98004', 'zipcode_98103', 'zipcode_98112',
#        'zipcode_98115', 'zipcode_98117', 'view_grade_6', 'view_grade_7',
#        'view_grade_8', 'view_grade_9'],
#       dtype='object')

# %%
#instantiate a linear regression object
lm_rfe = LinearRegression()

#fit the linear regression to the data
lm_rfe = lm_rfe.fit(X_train[selected_rfe], y_train)

y_rfe = np.exp(lm_rfe.predict(X_train[selected_rfe]))


trainRFE_rmse = np.sqrt(metrics.mean_squared_error(y_train, y_rfe))


print('Training Root Mean Squared Error:' , trainRFE_rmse)

y_pred_rfe = np.exp(lm_rfe.predict(X_test[selected_rfe]))

testRFE_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred_rfe))

print('Testing Root Mean Squared Error:' , testRFE_rmse)


print('Original: ', test_rmse, "vs. KBest: ", testK_rmse, "vs. RFE: ", testRFE_rmse)
# Out:
# Training Root Mean Squared Error: 602548.6390641982
# Testing Root Mean Squared Error: 618627.5770659541
# Original:  635164.0379784745 vs. KBest:  548454.8740815909 vs. RFE:  618627.5770659541

# %% [markdown]
# ## LASSO

# %%
## training the model
from sklearn.linear_model import Lasso

lasso = Lasso(alpha=.05, normalize=False)

lasso.fit(X_train,y_train)

y_train_pred_lasso = np.exp(lasso.predict(X_train))
y_pred_lasso = np.exp(lasso.predict(X_test))

train_rmse = metrics.mean_absolute_error(y_train, y_train_pred_lasso)
test_rmse = np.sqrt(metrics.mean_squared_error(y_test, y_pred_lasso))
print('Training Error: '+ str(train_rmse) )
print('Testing Error: '+ str(test_rmse) )

lasso_coef01 = pd.DataFrame(data=lasso.coef_).T
lasso_coef01.columns = X_train.columns
lasso_coef01 = lasso_coef01.T.sort_values(by=0).T
lasso_coef01.plot(kind='bar', title='Modal Coefficients', legend=False, figsize=(16,8))
# Out:
# Training Error: 488658.53977937653
# Testing Error: 517114.203910455

# %%
lasso_full = Lasso(alpha=.05, normalize=False)
lasso_full = lasso_full.fit(features_only, target)

# %%
with open('lasso_full.pickle', 'wb') as f:
    pickle.dump(lasso_full, f)

# %%
len(coefficient[coefficient[0] != 0])
# Out:
# 0

# %%
coefficient = lasso_coef01.T
coefficient[coefficient[0] != 0]
# Out:
# Empty DataFrame
# Columns: [0]
# Index: []

# %%
sns.set(style="white")

# Compute the correlation matrix
corr = X_train.iloc[:,:44].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(22, 18))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.residplot( y_train, y_train_pred_lasso,lowess=True, color="g")

# %%
sns.residplot( y_test, y_pred_lasso, lowess=True, color="g")

# %%
features['log_sqft_living'].corr(features['log_living_bed_ratio'])

# %%
features['log_sqft_living'].corr(features['view_grade'])

# %% [markdown]
# # FITTING TO FULL DATA

# %%
final_scaler = StandardScaler()
final_scaler.fit_transform(features[selected_columns])

# %%
final_model = LinearRegression()
final_model.fit(features[selected_columns], target)

# %% [markdown]
# ## POLYNOMIALS??

# %%
def create_polynomial_regression_model(degree):
  "Creates a polynomial regression model for the given degree"
  
  poly_features = PolynomialFeatures(degree=degree)
  
  # transforms the existing features to higher degree features.
  X_train_poly = poly_features.fit_transform(X_train)
  
  # fit the transformed features to Linear Regression
  poly_model = LinearRegression()
  poly_model.fit(X_train_poly, y_train)
  
  # predicting on training data-set
  y_train_predicted = poly_model.predict(X_train_poly)
  
  # predicting on test data-set
  y_test_predict = poly_model.predict(poly_features.fit_transform(X_test))
  
  # evaluating the model on training dataset
  rmse_train = np.sqrt(mean_squared_error(Y_train, y_train_predicted))
  r2_train = r2_score(y_train, y_train_predicted)
  
  # evaluating the model on test dataset
  rmse_test = np.sqrt(mean_squared_error(Y_test, y_test_predict))
  r2_test = r2_score(y_test, y_test_predict)
  
  print("The model performance for the training set")
  print("-------------------------------------------")
  print("RMSE of training set is {}".format(rmse_train))
  print("R2 score of training set is {}".format(r2_train))
  
  print("\n")
  
  print("The model performance for the test set")
  print("-------------------------------------------")
  print("RMSE of test set is {}".format(rmse_test))
  print("R2 score of test set is {}".format(r2_test))

# %%
create_polynomial_regression_model(3)

# %%
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(X_train[['']])

model = LinearRegression()
model.fit(x_poly, y_train)
y_poly_pred = model.predict(x_poly)

rmse = np.sqrt(mean_squared_error(y_train, y_poly_pred))
r2 = r2_score(y,y_poly_pred)
print(rmse)
print(r2)

plt.scatter(x, y, s=10)
# sort the values of x before line plot
sort_axis = operator.itemgetter(0)
sorted_zip = sorted(zip(X_train,y_poly_pred), key=sort_axis)
X_train, y_poly_pred = zip(*sorted_zip)
plt.plot(x, y_poly_pred, color='m')
plt.show()

# %%
features.columns[0:20]

# %%
features.columns[20:46]
