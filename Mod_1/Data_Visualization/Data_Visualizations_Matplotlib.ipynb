# %% [markdown]
# <h1 style='text-align:center'> Data Visualizations with Matplotlib <h1/>

# %% [markdown]
# # Starting Off:
#
# Why should we use data visualizations in our presentations?

# %% [markdown]
# <img src='images/marshall.gif' width=400/>

# %% [markdown]
# ## Why is Data Visualization Important?

# %%
import seaborn as sns
import pandas as pd

# %%
aq = pd.read_csv('aq.csv')

# %% [markdown]
# ##### Graphs

# %%
aq.describe()
# Out:
#               x1         x2         x3         x4
# count  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000
# std     3.316625   3.316625   3.316625   3.316625
# min     4.000000   4.000000   4.000000   8.000000
# 25%     6.500000   6.500000   6.500000   8.000000
# 50%     9.000000   9.000000   9.000000   8.000000
# 75%    11.500000  11.500000  11.500000   8.000000
# max    14.000000  14.000000  14.000000  19.000000

# %%
aq.sample(5)
# Out:
#      x1    x2    x3    x4
# 3   9.0   9.0   9.0   8.0
# 4  11.0  11.0  11.0   8.0
# 7   4.0   4.0   4.0  19.0
# 6   6.0   6.0   6.0   8.0
# 0  10.0  10.0  10.0   8.0

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# <img src='images/notsurprisedkirk.jpg' width=500/>

# %% [markdown]
# Data visualizations can help to provide more insight to a data set than what our descriptive statistics give us.

# %% [markdown]
# ## Matplotlib

# %%
from matplotlib import style, pyplot as plt
style.use('dark_background')
import numpy as np
# %matplotlib inline

# %%
plt.bar (['a', 'b', 'c'], [1,2,3])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# Matplotlib is a complex library (70,000 + lines of code!).This is further complicated becasue there are two main ways to create graphs in using this package.

# %% [markdown]
# ### Two Ways to Generate a Single Plot
#
# matplotlib provide two interfaces for plotting
# - MATLAB style plotting using pyplot
# - Object Oriented Interface

# %% [markdown]
# ### MATLAB style using plt.plot()

# %%
plt.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
plt.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], c=[1, 2, 3, 5], marker='^')
plt.xlim(0.5, 4.5)
plt.show()

# %% [markdown]
# ### OO Interface Using plt.subplots()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1, 2, 3, 4], [10, 20, 25, 30], color='lightblue', linewidth=3)
ax.scatter([0.3, 3.8, 1.2, 2.5], [11, 25, 9, 26], c=[1, 2, 3, 5], marker='^')
ax.set_xlim(0.5, 4.5)
plt.show()

# %% [markdown]
# ### What is the difference?
#
# In order to best understand how it creates graphs it's important to understand how objects are structured in matplotlib.
#
# A Figure in matplotlib is divided into two different objects.
# - Figure object
# - Axes object
#
#
# A Figure object can contain one or more axes objects. One axes represents one plot inside figure.

# %% [markdown]
# <img src='images/fig_map.webp'/>

# %%
#create a figure object
fig = plt.figure()

# Give the figure a title
fig.suptitle("Empty figure")

#create an axis object
ax = fig.add_subplot(1,1,1)

# Set the title of plot
ax.set_title("Empty plot")
plt.show()

# %%
fig = plt.figure()

# Generate a grid of 2x2 subplots and get
# axes object for 1st location
ax1 = fig.add_subplot(2,2,1)
ax1.set_title('First Location')

# Get the axes object for subplot at 2nd 
# location
ax2 = fig.add_subplot(2,2,2)
ax2.set_title('Second Location')

# Get the axes object for subplot at 3rd 
# location
ax3 = fig.add_subplot(2,2,3)
ax3.set_xlabel('Third Location')

# Get the axes object for subplot at 4th 
# location
ax4 = fig.add_subplot(2,2,4)
ax4.set_xlabel('Fourth Location')

# Display
plt.show()

# %% [markdown]
# Calling plt.plot() is just a convenient way to get the current Axes of the current Figure and then call its plot() method. This is what is meant by the assertion that the stateful interface always “implicitly tracks” the plot that it wants to reference.
#
# pyplot is home to a batch of functions that are really just wrappers around matplotlib’s object-oriented interface. For example, with plt.title(), there are corresponding setter and getter methods within the OO approach, ax.set_title() and ax.get_title().
#
#
# https://realpython.com/python-matplotlib-guide/
# https://medium.com/@kapil.mathur1987/matplotlib-an-introduction-to-its-object-oriented-interface-a318b1530aed

# %% [markdown]
# ## How do we add information and customize our plots?
#
# Almost every “element” of a chart is its own manipulable Python object, all the way down to the ticks and labels.

# %% [markdown]
# <img src="https://matplotlib.org/3.1.1/_images/anatomy.png" alt="anatomy" title="Anatomy of Figure" width="650" />

# %% [markdown]
# There are methods for each one of these elements that allow you to grab them and customize your graph.

# %%
ax.set_title('Line Graph')
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
# Out:
# Text(3.200000000000003, 0.5, 'Y Axis')

# %%
fig

# %% [markdown]
# You can instantiate multiple lines to the same plot by calling a plotting method on the same ax.

# %%
fig, ax = plt.subplots()
x = np.linspace(0, 5, 100)

ax.plot(x, x, label='linear', color='r', linestyle='dashed')
ax.plot(x, x**2, label='quadratic', color='g', linestyle='dashdot')
ax.plot(x, x**3, label='cubic', color='b', linestyle='dotted')

# %% [markdown]
# https://matplotlib.org/3.1.0/gallery/lines_bars_and_markers/linestyles.html

# %% [markdown]
# ## Using Documentation:
#
# The documentation is extremely confusing and can be difficult to find what you are looking for
#
# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot

# %% [markdown]
# Search through the documentation and find how to add a legend to the the graph above.

# %%
ax.____

# %% [markdown]
# ### Create a Figure with 2 Axes(Plots)

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot([1,2,3,4], [10,20,30,40])
ax[1].plot([1,2,3,4], [40,30,20,10])

# %% [markdown]
# #### Create a figure with 3 rows and two columns of plots

# %%
fig, axes = plt.subplots(3,2, figsize=(5, 8))

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12e601390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12ea43438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12dca3668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12daf61d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12dd75470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12dd874a8>]],
#       dtype=object)

# %% [markdown]
# Create some data to plot

# %%
# Use Numpy to create a list of numbers
# then transform those numbers using the sin function
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
axes[0][0].plot(x,y, color='aquamarine')
fig

# %% [markdown]
# #### Add the same chart to the second  row and first column

# %%
axes[1][0].plot(x,y, color='r')
axes[2][0].plot(x,y, color='g')
axes[0][1].plot(y,x, color='r')
axes[1][1].plot(x,y, color='r')
axes[2][1].plot(y,x, color='g')
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/lines.py in draw(self, renderer)
#     781                 self._set_gc_clip(gc)
#     782
# --> 783                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     784                 gc.set_foreground(lc_rgba, isRGBA=True)
#     785
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     231         except ValueError:
#     232             pass
# --> 233         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     234     # tuple color.
#     235     c = np.array(c)
#
# ValueError: Invalid RGBA argument: 'a'

# %% [markdown]
# #### Now lets add a title for the graph we just created?

# %%
axes[1][0].set_title('New Title')
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2054                         orientation=orientation,
#    2055                         dryrun=True,
# -> 2056                         **kwargs)
#    2057                     renderer = self.figure._cachedRenderer
#    2058                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     525
#     526         else:
# --> 527             FigureCanvasAgg.draw(self)
#     528             renderer = self.get_renderer()
#     529             with cbook._setattr_cm(renderer, dpi=self.figure.dpi), \
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/lines.py in draw(self, renderer)
#     781                 self._set_gc_clip(gc)
#     782
# --> 783                 lc_rgba = mcolors.to_rgba(self._color, self._alpha)
#     784                 gc.set_foreground(lc_rgba, isRGBA=True)
#     785
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     175         rgba = None
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#     179             _colors_full_map.cache[c, alpha] = rgba
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     231         except ValueError:
#     232             pass
# --> 233         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     234     # tuple color.
#     235     c = np.array(c)
#
# ValueError: Invalid RGBA argument: 'a'

# %% [markdown]
# We can also add a title to the entire figure

# %%
fig.suptitle('No axes on this figure')
fig

# %% [markdown]
# ### Defining a function to Plot graphs:
#
# Often when you are exploring your data you will create multiple graphs to look at many different variables. If you create a function at the beginning, you can save time from constantly copying and pasting.

# %%
 # Define a function called plot_timeseries
def plot_timeseries(axes, 
                    x_data, 
                    y_data, color):

  # Plot the inputs x,y in the provided color
  axes.plot(x_data, y_data, color=color)

  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %% [markdown]
# ### Using the function:
#
# Create a figure and axes to feed the function.

# %%
fig, ax = plt.subplots()

plot_timeseries(ax, x, y, 'r')

# %% [markdown]
# Now create your own function that also takes a title, x_label and y_label and adds those to the graph as well

# %%
 # Define a function called plot_timeseries
def plot_timeseries(axes, x_data, y_data, color, ____,  ____):

  # Plot the inputs x,y in the provided color
  axes.plot(____, ____, color=color)

# Set the x-axis label
  axes.____(____)

  # Set the y-axis label
  axes.____(____, color=color)
    
  # Set the colors tick params for y-axis
  axes.tick_params('y', colors=color)

# %% [markdown]
# #### Create a new fig and ax and call your updated function using these new objects

# %% [markdown]
# ### Adding multiple axis to the same graph

# %%
#create a new set
y_2 = np.cos(x)

# %%
# Create a twin Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, x, y_2, "red", "X_Axis", "Cosine")

# plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# Seaborn is built on top of Matplotlib. Seaborn adds some styling to existing matplotlib graphs as well as adds some additional graphing capabilities.

# %%
import seaborn as sns
sns.set()

# %%
plt.plot([1,2], [3,4])

# %% [markdown]
# The most useful aspect of seaborn is that it allows you to use Pandas DataFrame Objects directly.

# %%
#loads tips dataset
tips = sns.load_dataset("tips")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-39-12ace3a3b4ff> in <module>
#       1 #loads tips dataset
# ----> 2 tips = sns.load_dataset("tips")
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     246     url_type, path = splittype(url)
#     247
# --> 248     with contextlib.closing(urlopen(url, data)) as fp:
#     249         headers = fp.info()
#     250
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in http_response(self, request, response)
#     640         if not (200 <= code < 300):
#     641             response = self.parent.error(
# --> 642                 'http', request, response, code, msg, hdrs)
#     643
#     644         return response
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in error(self, proto, *args)
#     568         if http_err:
#     569             args = (dict, 'default', 'http_error_default') + orig_args
# --> 570             return self._call_chain(*args)
#     571
#     572 # XXX probably also want an abstract factory that knows when it makes
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502         for handler in handlers:
#     503             func = getattr(handler, meth_name)
# --> 504             result = func(*args)
#     505             if result is not None:
#     506                 return result
#
# /opt/anaconda3/envs/learn-env/lib/python3.6/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     648 class HTTPDefaultErrorHandler(BaseHandler):
#     649     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 650         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     651
#     652 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 500: Internal Server Error

# %%
tips.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-53a0cf752a4f> in <module>
# ----> 1 tips.head()
#
# NameError: name 'tips' is not defined

# %%
sns.scatterplot('total_bill', 'tip', data=tips)

# Similar to matplotlib, you can add a ";" to remove the "object output"
sns.scatterplot('total_bill', 'tip', data=tips);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-80eeca216f86> in <module>
# ----> 1 sns.scatterplot('total_bill', 'tip', data=tips)
#       2
#       3 # Similar to matplotlib, you can add a ";" to remove the "object output"
#       4 sns.scatterplot('total_bill', 'tip', data=tips);
#
# NameError: name 'tips' is not defined

# %% [markdown]
# ## Resources

# %% [markdown]
# - https://www.ted.com/talks/david_mccandless_the_beauty_of_data_visualization#t-503926
# - https://realpython.com/python-matplotlib-guide/
# - https://www.darkhorseanalytics.com/blog/data-looks-better-naked/

# %% [markdown]
# - https://pudding.cool/
# - http://setosa.io/#/
