# %% [markdown]
# ## Starting Off
#
# Message me one question you have about APIs. Any question at all

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
from  keys  import  client_id, api_key

# %%
print(api_key)
# Out:
# vT-JhBHOEl66pQyl1GIt4CDoXwipUxGIZ93XZv3-eiy81OYyeefp_IfLs54u7zRBMSqXFOxSRbr3yMBWEy-Rt0L0UjSHXSODIXWVXqTecikY_YM_z0nRpLiGZZWPXnYx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'ramen'

#where do you want to perform this search
location = 'bushwick'

# what is your other parameter you want to search against
price = '1,2,3'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "price": price,
                "limit": 50
            }

# %%
url_params
# Out:
# {'term': 'ramen', 'location': 'bushwick', 'price': '1,2,3', 'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '{"businesses": [{"id": "e-G1yC5u8LOcQ-fx0Lxthw", "alias": "ajihei-bushwick-brooklyn", "name": "Ajihei Bushwick", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/7QCedXet5RI8rF0dxB2FHA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg", "review_count": 79, "categories": [{"alias": "sushi", "title": "Sushi Bars"}, {"alias": "ramen", "title": "Ramen"}, {"alias": "salad", "title": "Salad"}], "rating": 4.5, "coordinates": {"latitude": 40.70416, "longitude": -73.92799}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "156 Knickerbocker Ave", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11237", "country": "US", "state": "NY", "display_address": ["156 Knickerbocker Ave", "Brooklyn, NY 11237"]}, "phone": "+17185522065", "display_phone": "(718) 552-2065", "distance": 1110.9503886333598}, {"id": "G4qZvheX74VwYvek7I8iQg", "alias": "buntopia-brooklyn", "name": "Buntopia", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/mL7sje7bFV_79mg4pJK8eA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/buntopia-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg", "review_count": 290, "categories": [{"alias": "asianfusion", "title": "Asian Fusion"}, {"alias": "ramen", "title": "Ramen"}, {"alias": "sushi", "title": "Sushi Bars"}], "rating": 4.5, "coordinates": {"latitude": 40.69598, "longitude": -73.93398}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "994 Broadway", "address2": null, "address3": "", "city": "Brooklyn", "zip_code": "11221", "country": "US", "state": "NY", "display_address": ["994 Broadway", "Brooklyn, NY 11221"]}, "phone": "+13474353660", "display_phone": "(347) 435-3660", "distance": 1081.5446435111458}, {"id": "JRmQRFEEnSUdAcesHun9AQ", "alias": "ichiran-brooklyn-brooklyn", "name": "ICHIRAN - Brooklyn", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/wDXO7-SIqQUOn6B8apTVvQ/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/ichiran-brooklyn-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg", "review_count": 1130, "categories": [{"alias": "ramen", "title": "Ramen"}, {"alias": "noodles", "title": "Noodles"}, {"alias": "soup", "title": "Soup"}], "rating": 3.5, "coordinates": {"latitude": 40.707587, "longitude": -73.933271}, "transactions": [], "price": "$$", "location": {"address1": "374 Johnson Ave", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11206", "country": "US", "state": "NY", "display_address": ["374 Johnson Ave", "Brooklyn, NY 11206"]}, "phone": "+17183810491", "display_phone": "(718) 381-0491", "distance": 1678.3123837525588}, {"id": "7xpbioe88rnW7JjzLEQeRg", "alias": "samurai-papa-brooklyn-2", "name": "Samurai Papa", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/H9YugRMONrxKBkAFx_6yPg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/samurai-papa-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg", "review_count": 269, "categories": [{"alias": "ramen", "title": "Ramen"}], "rating": 4.5, "coordinates": {"latitude": 40.702892072912, "longitude": -73.943588398397}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "32 Varet St", "address2": "", "address3": "", "city": "Brooklyn", "zip_code": "11206", "country": "US", "state": "NY", "display_address": ["32 Varet St", "Brooklyn, NY 11206"]}, "phone": "+17185997171", "display_phone": "(718) 599-7171", "distance": 2056.670242790492}, {"id": "nhez4xxvwwYIQEN2Vrj9mQ", "alias": "yuji-ramen-brooklyn-3", "name": "YUJI Ramen", "image_url": "https://s3-media2.fl.ye ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'e-G1yC5u8LOcQ-fx0Lxthw',
#    'alias': 'ajihei-bushwick-brooklyn',
#    'name': 'Ajihei Bushwick',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7QCedXet5RI8rF0dxB2FHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 79,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70416, 'longitude': -73.92799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17185522065',
#    'display_phone': '(718) 552-2065',
#    'distance': 1110.9503886333598},
#   {'id': 'G4qZvheX74VwYvek7I8iQg',
#    'alias': 'buntopia-brooklyn',
#    'name': 'Buntopia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mL7sje7bFV_79mg4pJK8eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buntopia-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 290,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69598, 'longitude': -73.93398},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '994 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['994 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+13474353660',
#    'display_phone': '(347) 435-3660',
#    'distance': 1081.5446435111458},
#   {'id': 'JRmQRFEEnSUdAcesHun9AQ',
#    'alias': 'ichiran-brooklyn-brooklyn',
#    'name': 'ICHIRAN - Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wDXO7-SIqQUOn6B8apTVvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichiran-brooklyn-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 1130,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.707587, 'longitude': -73.933271},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '374 Johnson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['374 Johnson Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17183810491',
#    'display_phone': '(718) 381-0491',
#    'distance': 1678.3123837525588},
#   {'id': '7xpbioe88rnW7JjzLEQeRg',
#    'alias': 'samurai-papa-brooklyn-2',
#    'name': 'Samurai Papa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H9YugRMONrxKBkAFx_6yPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-papa-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 269,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702892072912, 'longitude': -73.943588398397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Varet St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Varet St', 'Brooklyn, NY 11206']},
#    'phone': '+17185997171',
#    'display_phone': '(718) 599-7171',
#    'distance': 2056.670242790492},
#   {'id': 'nhez4xxvwwYIQEN2Vrj9mQ',
#    'alias': 'yuji-ramen-brooklyn-3',
#    'name': 'YUJI Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BSnln7Ugk-eS6K21vN1vrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuji-ramen-brooklyn-3?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 130,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712527, 'longitude': -73.9487788},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2993.1558549969072},
#   {'id': 'hdiTkEnD14VpXNl-APTg2g',
#    'alias': 'nana-ramen-brooklyn',
#    'name': 'Nana Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LXLGS9Go-Fh20inuHsxzsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nana-ramen-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 154,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6815479, 'longitude': -73.9289913},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '330 Malcolm X Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+19292100589',
#    'display_phone': '(929) 210-0589',
#    'distance': 1696.5598909463495},
#   {'id': 'ujozQCThEuSfEXi5_6ZTPQ',
#    'alias': 'ramen-setagaya-brooklyn',
#    'name': 'Ramen Setagaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzLlGf3cgJMSpXGMqShDDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-setagaya-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 260,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7147999, 'longitude': -73.96115},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '280 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182188508',
#    'display_phone': '(718) 218-8508',
#    'distance': 3995.0476710927433},
#   {'id': '0gPXct_l_82phIEoKdtWZw',
#    'alias': 'ryujin-brooklyn-8',
#    'name': 'RYUJIN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qok9QqxbVYHMHETgZ2gs9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryujin-brooklyn-8?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 267,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711178187852,
#     'longitude': -73.9506256676857},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '513 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17187099888',
#    'display_phone': '(718) 709-9888',
#    'distance': 3027.565012617573},
#   {'id': 'GBk_i2qnjMtQIt_ntJpzbw',
#    'alias': 'ramen-andante-brooklyn-2',
#    'name': 'Ramen Andante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eVeSjIIG5gXuZ6nAknFK_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-andante-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 59,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7148695, 'longitude': -73.9625803},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '130 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+19293970010',
#    'display_phone': '(929) 397-0010',
#    'distance': 4099.873518167904},
#   {'id': 'qd9_gxrmskbOT6OLN9sShA',
#    'alias': 'dock-asian-eatery-brooklyn-4',
#    'name': 'Dock Asian Eatery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hG7_CwCjCuUW8IrbOOA6ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dock-asian-eatery-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 129,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70628, 'longitude': -73.92274},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '22 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17188213900',
#    'display_phone': '(718) 821-3900',
#    'distance': 1194.4902218404427},
#   {'id': 'v3qQvMjj4KSZ4dPU4ERyiw',
#    'alias': 'ramen-spot-brooklyn-4',
#    'name': 'Ramen Spot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xj3ctOgKFjIwEACzDS6W6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-spot-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 85,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7268634, 'longitude': -73.952345},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '760 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['760 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17188092527',
#    'display_phone': '(718) 809-2527',
#    'distance': 4357.526523004717},
#   {'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#    'alias': 'chuko-brooklyn-2',
#    'name': 'Chuko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MD7Q6u1eUGzEDBtr6Qyimw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 1064,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680784, 'longitude': -73.967455},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '565 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['565 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13474259570',
#    'display_phone': '(347) 425-9570',
#    'distance': 4236.568327876994},
#   {'id': 'IuMvrvXTTZm4NQYO1O1dbg',
#    'alias': 'kuma-nyc-brooklyn-2',
#    'name': 'Kuma NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aRGL9irXCX7SojclW2Libw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kuma-nyc-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 46,
#    'categories': [{'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.699183, 'longitude': -73.91304},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1520 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1520 Myrtle Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183663790',
#    'display_phone': '(718) 366-3790',
#    'distance': 791.767731756538},
#   {'id': 'ooHTw6KGNXsKj5TmyHKVuQ',
#    'alias': 'lucys-vietnamese-bushwick-bushwick',
#    'name': "Lucy's Vietnamese Bushwick",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d842GjU-5cUshM3opPmEMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucys-vietnamese-bushwick-bushwick?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 470,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699661, 'longitude': -73.916012},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '262 Irving Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bushwick',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['262 Irving Ave', 'Bushwick, NY 11237']},
#    'phone': '+13472401599',
#    'display_phone': '(347) 240-1599',
#    'distance': 633.2413911641898},
#   {'id': 'Dv28TvKBh_8i6W02uAaMKw',
#    'alias': 'samurai-papa-bs-brooklyn',
#    'name': 'Samurai Papa BS',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKpVaDY0ppHibH2R0BbFLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-papa-bs-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 153,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68981, 'longitude': -73.95101},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '594 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['594 Lafayette Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17183988181',
#    'display_phone': '(718) 398-8181',
#    'distance': 2599.9679155852905},
#   {'id': 'xYDays-olVw50rdusxW5Rw',
#    'alias': 'wanpaku-brooklyn',
#    'name': 'Wanpaku',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fKWkpsQn7txEg_220UUZ3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanpaku-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 77,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72355, 'longitude': -73.95092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '621 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833139',
#    'display_phone': '(718) 383-3139',
#    'distance': 3993.2426403402364},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 455,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3000.166602714201},
#   {'id': 'Neiw4AB_s7BpLSxyUrSXBQ',
#    'alias': 'sushi-and-noodles-brooklyn-13',
#    'name': 'Sushi & Noodles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gyhk02Ro7acnmoVYxBNXwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-and-noodles-brooklyn-13?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 141,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70347, 'longitude': -73.92577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Troutman St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Troutman St', 'Brooklyn, NY 11237']},
#    'phone': '+17183662825',
#    'display_phone': '(718) 366-2825',
#    'distance': 952.3481408101222},
#   {'id': '-fRgp3gv0-R6y9YOJX8ZVA',
#    'alias': 'warude-brooklyn',
#    'name': 'Warude',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/73_WgakzKOr2t4xjDE7__Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/warude-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 65,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846262, 'longitude': -73.9440354},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '385 Tompkins Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['385 Tompkins Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17186844449',
#    'display_phone': '(718) 684-4449',
#    'distance': 2282.1465318323735},
#   {'id': 'YwpP-mgXV5N35xhLibLw5g',
#    'alias': 'mos-original-brooklyn',
#    'name': "Mo's Original",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SsVjlE0y0p1ghVHLL2gJOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mos-original-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 86,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66127, 'longitude': -73.95342},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '453 Rogers Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['453 Rogers Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17185130698',
#    'display_phone': '(718) 513-0698',
#    'distance': 4680.352902485553},
#   {'id': 'ZaJS8EKQNSaQpwpmgN-vVw',
#    'alias': 'samurai-mama-brooklyn',
#    'name': 'Samurai Mama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU4mCy9pszj-Kx3WzcAXQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-mama-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 592,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140208838114,
#     'longitude': -73.960325717926},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '205 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185996161',
#    'display_phone': '(718) 599-6161',
#    'distance': 3884.61133831763},
#   {'id': 'iYFauSnqLxvr4HTY_cIElg',
#    'alias': 'little-mo-brooklyn',
#    'name': 'Little Mo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f2pS7K-QYKqA97dr9cBmVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-mo-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 317,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69701, 'longitude': -73.93368},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1158 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1158 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+19292108100',
#    'display_phone': '(929) 210-8100',
#    'distance': 1066.5583968943095},
#   {'id': 'ZrzSDDj54aUlPqn4MQMKeQ',
#    'alias': 'momo-sushi-shack-brooklyn',
#    'name': 'Momo Sushi Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZfIEda7Sh5fXBxbrTm9fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momo-sushi-shack-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 658,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7051406133, 'longitude': -73.933340055132},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43 Bogart St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Bogart St', 'Brooklyn, NY 11206']},
#    'phone': '+17184186666',
#    'display_phone': '(718) 418-6666',
#    'distance': 1475.7293427113775},
#   {'id': 'TZG0qTIGdeOtCkBrSU6v0Q',
#    'alias': 'minami-lounge-brooklyn',
#    'name': 'Minami Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bDECpLa89adXlMWDv1bK3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minami-lounge-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 47,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70944, 'longitude': -73.95566},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '299 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+19179091896',
#    'display_phone': '(917) 909-1896',
#    'distance': 3283.8083086877627},
#   {'id': '74SKT4IxG-hXz71nRbheng',
#    'alias': 'ozi-dumplings-brooklyn-2',
#    'name': 'Ozi Dumplings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/glLLmQO-W-5RLuaXu8iz4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozi-dumplings-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 129,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70381, 'longitude': -73.933159},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Bogart St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Bogart St', 'Brooklyn, NY 11206']},
#    'phone': '+17189136316',
#    'display_phone': '(718) 913-6316',
#    'distance': 1369.0906097136237},
#   {'id': 'NEK3UUNhh5YLhxfrjDu2Og',
#    'alias': 'darlings-brooklyn',
#    'name': 'Darlings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mDAfY2zXQWR3eTdq8Ymatw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darlings-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 24,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699996, 'longitude': -73.9197525},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '242 Himrod St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Himrod St', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 502.66236037888024},
#   {'id': 'KfFXfxN6qzk_dTcQjsK-OQ',
#    'alias': 'fukuyama-sushi-and-ramen-brooklyn-2',
#    'name': 'Fukuyama Sushi & Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j-z7MkTDUokBhAJo84YxoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fukuyama-sushi-and-ramen-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 43,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.713916, 'longitude': -73.948283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '622 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187821496',
#    'display_phone': '(718) 782-1496',
#    'distance': 3066.164008122554},
#   {'id': 'EG8MnctXEOXkm7b_yge7Pw',
#    'alias': 'osakana-brooklyn',
#    'name': 'Osakana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/shWR3yKyQpGlAyzlwHoAwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osakana-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 47,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71224, 'longitude': -73.94376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '290 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+16466534633',
#    'display_phone': '(646) 653-4633',
#    'distance': 2659.2048959044128},
#   {'id': '7USePx0k_ENmwrw625X9kA',
#    'alias': 'jin-ramen-sushi-ridgewood',
#    'name': 'Jin Ramen Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rMJCqL0M15BXTGvgMOyOPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jin-ramen-sushi-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 80,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70772, 'longitude': -73.89722},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '66-41 Fresh Pond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66-41 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+13479873959',
#    'display_phone': '(347) 987-3959',
#    'distance': 2424.2730761546527},
#   {'id': 'e_hmhxJbpSPAGEfim86PVQ',
#    'alias': 'gentle-perch-brooklyn',
#    'name': 'Gentle Perch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6NjW0WpkopEaJydy_MqnYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gentle-perch-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 66,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705106, 'longitude': -73.942587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '112 Graham Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+19292980041',
#    'display_phone': '(929) 298-0041',
#    'distance': 2093.8081161131995},
#   {'id': '3gqKLANaXNsHZnPDjKrcTg',
#    'alias': 'win-son-brooklyn-4',
#    'name': 'Win Son',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EXCnl7qaa1wEQMWMI6ZqRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/win-son-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 484,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70747, 'longitude': -73.94339},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '159 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13474576010',
#    'display_phone': '(347) 457-6010',
#    'distance': 2297.6593167539736},
#   {'id': 'VF3Ep2NQN8FqSCV8ySulSA',
#    'alias': '19-cafe-new-york',
#    'name': '19 Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mesyWl6-K3LzifhKEwcRdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/19-cafe-new-york?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70515, 'longitude': -73.9444199},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '84 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 Manhattan Ave', 'New York, NY 11206']},
#    'phone': '+17183878777',
#    'display_phone': '(718) 387-8777',
#    'distance': 2229.1185954195703},
#   {'id': 'H5jHfG4ZkNPaG6vojmAXww',
#    'alias': 'chingoo-restaurant-brooklyn',
#    'name': 'Chingoo Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGLcBaBHhGBFC5u1BRNfhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chingoo-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 34,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715796, 'longitude': -73.944733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '373 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['373 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13479161269',
#    'display_phone': '(347) 916-1269',
#    'distance': 2997.924651025122},
#   {'id': '6wJOojpF2c4lLeBNbTBB0A',
#    'alias': 'baoburg-brooklyn-2',
#    'name': 'Baoburg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvXZWKSplu8HEMDwM8waog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baoburg-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 214,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7234929271998,
#     'longitude': -73.9503321851175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '614 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['614 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183490011',
#    'display_phone': '(718) 349-0011',
#    'distance': 3957.3383811607714},
#   {'id': 'NCnOkzbyfzDltnBnJySfzw',
#    'alias': 'amami-bar-and-restaurant-brooklyn',
#    'name': 'Amami Bar and Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzSSNiTIcoEWoRm3fQphtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amami-bar-and-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 142,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723548, 'longitude': -73.952194},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '57 Nassau Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19179091568',
#    'display_phone': '(917) 909-1568',
#    'distance': 4057.6647035585934},
#   {'id': 'IoAUbSudW1Mds5_XY_01Rg',
#    'alias': 'mission-chinese-food-brooklyn',
#    'name': 'Mission Chinese Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UB19gADyJHsF9M7yrnTCtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mission-chinese-food-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 74,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70933, 'longitude': -73.92315},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '599 Johnson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['599 Johnson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186283731',
#    'display_phone': '(718) 628-3731',
#    'distance': 1536.9682941592007},
#   {'id': 'BlzlywklvYdek5uk_NCX9g',
#    'alias': 'suzume-brooklyn',
#    'name': 'Suzume',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJ6jgbfh1BIofEAz2ztaCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suzume-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 301,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7131652, 'longitude': -73.9494479},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '545 Lorimer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184860200',
#    'display_phone': '(718) 486-0200',
#    'distance': 3081.685928676039},
#   {'id': 'eBljpfHpo3m6oc5SFw-mLw',
#    'alias': 'falansai-brooklyn-2',
#    'name': 'Falansai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RxOKUavhfM8Ap8iYmgCQuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/falansai-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 216,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70676, 'longitude': -73.92877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '112 Harrison Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Harrison Pl', 'Brooklyn, NY 11237']},
#    'phone': '+13475991190',
#    'display_phone': '(347) 599-1190',
#    'distance': 1390.682726451697},
#   {'id': 'vmU2oLglodmiFK0iQGzDFw',
#    'alias': 'sally-roots-brooklyn',
#    'name': 'Sally Roots',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KvO6-IUnFcSO9I1kZFYwXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-roots-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 253,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702756, 'longitude': -73.916372},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '195 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+13474250888',
#    'display_phone': '(347) 425-0888',
#    'distance': 892.0227449875638},
#   {'id': 'zJcxZQbTSAP3q4Fy-6WAyw',
#    'alias': 'shalom-japan-brooklyn',
#    'name': 'Shalom Japan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RDRo2F_OQ0XtJEefYBqoFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shalom-japan-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 275,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7091679, 'longitude': -73.9558028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '310 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183884012',
#    'display_phone': '(718) 388-4012',
#    'distance': 3286.364089590897},
#   {'id': 'FYWwW5lcxKzaA98Xgw8bqA',
#    'alias': 'hanon-brooklyn',
#    'name': 'hanon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RQz8Yzxa66xQ07DxVgsgbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanon-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 103,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7134488, 'longitude': -73.9513445},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '436 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477991433',
#    'display_phone': '(347) 799-1433',
#    'distance': 3226.2627957803984},
#   {'id': 'EvLkJaWEXTZ8QNBrxOhDsA',
#    'alias': 'bunker-brooklyn',
#    'name': 'Bunker',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UoY5PqkIQ1vtQblao9t4zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunker-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 718,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7105638, 'longitude': -73.9233984},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '99 Scott Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 Scott Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183864282',
#    'display_phone': '(718) 386-4282',
#    'distance': 1674.0448342669256},
#   {'id': 'LHcpOjPtc8QQCrFiRFjWyA',
#    'alias': 'slow-loris-brooklyn',
#    'name': 'Slow Loris',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iIN136Y8pbolq2gdWtkcfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slow-loris-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 86,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6601311, 'longitude': -73.9607934},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '556 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['556 Flatbush Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17184847170',
#    'display_phone': '(718) 484-7170',
#    'distance': 5164.849281134537},
#   {'id': 'KrJ6m_TkxBAPPSNH-G7rvQ',
#    'alias': 'u-gu-brooklyn-4',
#    'name': 'U-gu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/otCFJmUAou8b89de_Lo7SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-gu-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 128,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69393, 'longitude': -73.96284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '541 Myrtle Ave',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['541 Myrtle Ave', 'Ste B', 'Brooklyn, NY 11205']},
#    'phone': '+17188570222',
#    'display_phone': '(718) 857-0222',
#    'distance': 3517.2576174803976},
#   {'id': 'Op43gk4VHEhENJGs-FKi3g',
#    'alias': 'garlic-to-the-chicken-ridgewood',
#    'name': 'Garlic To the Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lX3v6JQXGNKyT9Y4c7BfCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garlic-to-the-chicken-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 81,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7049523, 'longitude': -73.9022751},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '66-92 Forest Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66-92 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+13476892670',
#    'display_phone': '(347) 689-2670',
#    'distance': 1901.6867809382948},
#   {'id': 'fHHpSKT9u7PQBYaMW5cEkA',
#    'alias': 'trad-room-brooklyn-2',
#    'name': 'Trad Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4eW608lQXYBaT7fDSLMpBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trad-room-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 46,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68388, 'longitude': -73.92952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '266 Malcolm X Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['266 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+13472405760',
#    'display_phone': '(347) 240-5760',
#    'distance': 1482.353521722662},
#   {'id': '0zcgBHXbaJn0ZxgpcTJ1aQ',
#    'alias': 'nostrand-cafe-bedford-stuyvesant',
#    'name': 'Nostrand Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svDue-WeWJImXRsYNTvknQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nostrand-cafe-bedford-stuyvesant?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 105,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68978, 'longitude': -73.951142},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '261 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bedford-Stuyvesant',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Nostrand Ave', 'Bedford-Stuyvesant, NY 11216']},
#    'phone': '+17189758588',
#    'display_phone': '(718) 975-8588',
#    'distance': 2615.0332012479876},
#   {'id': '1m1iOc8EplJ4tiCez7hf2Q',
#    'alias': '750-myrtle-diner-brooklyn',
#    'name': '750 Myrtle Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mMU65sTdliF8vLWy_DLArw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/750-myrtle-diner-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 114,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.694779, 'longitude': -73.952807},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '750 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['750 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187585298',
#    'display_phone': '(718) 758-5298',
#    'distance': 2669.170419098156},
#   {'id': '30pqvzHrCNmnodJCRyzrTg',
#    'alias': 'snacky-brooklyn',
#    'name': 'Snacky',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3a3ihfFB5jp8AQTj_ouZJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snacky-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 193,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71439, 'longitude': -73.9607},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '187 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17184864848',
#    'display_phone': '(718) 486-4848',
#    'distance': 3932.359000851308},
#   {'id': '98URsYAwTfXRPP5e1ONPug',
#    'alias': 'maya-bed-stuy-brooklyn-4',
#    'name': 'Maya Bed Stuy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7hMQGWWcY2PTiHciQjAhrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maya-bed-stuy-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 89,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68719, 'longitude': -73.944167},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '563 Gates Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['563 Gates Ave', 'Brooklyn, NY 11221']},
#    'phone': '+13473266003',
#    'display_phone': '(347) 326-6003',
#    'distance': 2155.4898321203373}],
#  'total': 132,
#  'region': {'center': {'longitude': -73.9211654663086,
#    'latitude': 40.69560420717647}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': 'e-G1yC5u8LOcQ-fx0Lxthw',
#    'alias': 'ajihei-bushwick-brooklyn',
#    'name': 'Ajihei Bushwick',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7QCedXet5RI8rF0dxB2FHA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 79,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70416, 'longitude': -73.92799},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '156 Knickerbocker Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17185522065',
#    'display_phone': '(718) 552-2065',
#    'distance': 1110.9503886333598},
#   {'id': 'G4qZvheX74VwYvek7I8iQg',
#    'alias': 'buntopia-brooklyn',
#    'name': 'Buntopia',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mL7sje7bFV_79mg4pJK8eA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buntopia-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 290,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69598, 'longitude': -73.93398},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '994 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['994 Broadway', 'Brooklyn, NY 11221']},
#    'phone': '+13474353660',
#    'display_phone': '(347) 435-3660',
#    'distance': 1081.5446435111458},
#   {'id': 'JRmQRFEEnSUdAcesHun9AQ',
#    'alias': 'ichiran-brooklyn-brooklyn',
#    'name': 'ICHIRAN - Brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wDXO7-SIqQUOn6B8apTVvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ichiran-brooklyn-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 1130,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.707587, 'longitude': -73.933271},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '374 Johnson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['374 Johnson Ave', 'Brooklyn, NY 11206']},
#    'phone': '+17183810491',
#    'display_phone': '(718) 381-0491',
#    'distance': 1678.3123837525588},
#   {'id': '7xpbioe88rnW7JjzLEQeRg',
#    'alias': 'samurai-papa-brooklyn-2',
#    'name': 'Samurai Papa',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H9YugRMONrxKBkAFx_6yPg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-papa-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 269,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.702892072912, 'longitude': -73.943588398397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Varet St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Varet St', 'Brooklyn, NY 11206']},
#    'phone': '+17185997171',
#    'display_phone': '(718) 599-7171',
#    'distance': 2056.670242790492},
#   {'id': 'nhez4xxvwwYIQEN2Vrj9mQ',
#    'alias': 'yuji-ramen-brooklyn-3',
#    'name': 'YUJI Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BSnln7Ugk-eS6K21vN1vrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yuji-ramen-brooklyn-3?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 130,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.712527, 'longitude': -73.9487788},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2993.1558549969072},
#   {'id': 'hdiTkEnD14VpXNl-APTg2g',
#    'alias': 'nana-ramen-brooklyn',
#    'name': 'Nana Ramen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LXLGS9Go-Fh20inuHsxzsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nana-ramen-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 154,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6815479, 'longitude': -73.9289913},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '330 Malcolm X Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['330 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+19292100589',
#    'display_phone': '(929) 210-0589',
#    'distance': 1696.5598909463495},
#   {'id': 'ujozQCThEuSfEXi5_6ZTPQ',
#    'alias': 'ramen-setagaya-brooklyn',
#    'name': 'Ramen Setagaya',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzLlGf3cgJMSpXGMqShDDQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-setagaya-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 260,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7147999, 'longitude': -73.96115},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '280 Bedford Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['280 Bedford Ave', 'Brooklyn, NY 11249']},
#    'phone': '+17182188508',
#    'display_phone': '(718) 218-8508',
#    'distance': 3995.0476710927433},
#   {'id': '0gPXct_l_82phIEoKdtWZw',
#    'alias': 'ryujin-brooklyn-8',
#    'name': 'RYUJIN',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qok9QqxbVYHMHETgZ2gs9w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ryujin-brooklyn-8?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 267,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.711178187852,
#     'longitude': -73.9506256676857},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '513 Grand St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['513 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17187099888',
#    'display_phone': '(718) 709-9888',
#    'distance': 3027.565012617573},
#   {'id': 'GBk_i2qnjMtQIt_ntJpzbw',
#    'alias': 'ramen-andante-brooklyn-2',
#    'name': 'Ramen Andante',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eVeSjIIG5gXuZ6nAknFK_A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-andante-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 59,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7148695, 'longitude': -73.9625803},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '130 Grand St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11249',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#    'phone': '+19293970010',
#    'display_phone': '(929) 397-0010',
#    'distance': 4099.873518167904},
#   {'id': 'qd9_gxrmskbOT6OLN9sShA',
#    'alias': 'dock-asian-eatery-brooklyn-4',
#    'name': 'Dock Asian Eatery',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hG7_CwCjCuUW8IrbOOA6ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dock-asian-eatery-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 129,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70628, 'longitude': -73.92274},
#    'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '22 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17188213900',
#    'display_phone': '(718) 821-3900',
#    'distance': 1194.4902218404427},
#   {'id': 'v3qQvMjj4KSZ4dPU4ERyiw',
#    'alias': 'ramen-spot-brooklyn-4',
#    'name': 'Ramen Spot',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xj3ctOgKFjIwEACzDS6W6g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ramen-spot-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 85,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7268634, 'longitude': -73.952345},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '760 Manhattan Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['760 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17188092527',
#    'display_phone': '(718) 809-2527',
#    'distance': 4357.526523004717},
#   {'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#    'alias': 'chuko-brooklyn-2',
#    'name': 'Chuko',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MD7Q6u1eUGzEDBtr6Qyimw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 1064,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.680784, 'longitude': -73.967455},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '565 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11238',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['565 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#    'phone': '+13474259570',
#    'display_phone': '(347) 425-9570',
#    'distance': 4236.568327876994},
#   {'id': 'IuMvrvXTTZm4NQYO1O1dbg',
#    'alias': 'kuma-nyc-brooklyn-2',
#    'name': 'Kuma NYC',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aRGL9irXCX7SojclW2Libw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kuma-nyc-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 46,
#    'categories': [{'alias': 'poke', 'title': 'Poke'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.699183, 'longitude': -73.91304},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1520 Myrtle Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1520 Myrtle Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183663790',
#    'display_phone': '(718) 366-3790',
#    'distance': 791.767731756538},
#   {'id': 'ooHTw6KGNXsKj5TmyHKVuQ',
#    'alias': 'lucys-vietnamese-bushwick-bushwick',
#    'name': "Lucy's Vietnamese Bushwick",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d842GjU-5cUshM3opPmEMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lucys-vietnamese-bushwick-bushwick?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 470,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699661, 'longitude': -73.916012},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '262 Irving Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bushwick',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['262 Irving Ave', 'Bushwick, NY 11237']},
#    'phone': '+13472401599',
#    'display_phone': '(347) 240-1599',
#    'distance': 633.2413911641898},
#   {'id': 'Dv28TvKBh_8i6W02uAaMKw',
#    'alias': 'samurai-papa-bs-brooklyn',
#    'name': 'Samurai Papa BS',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKpVaDY0ppHibH2R0BbFLg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-papa-bs-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 153,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.68981, 'longitude': -73.95101},
#    'transactions': ['pickup'],
#    'price': '$$',
#    'location': {'address1': '594 Lafayette Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['594 Lafayette Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17183988181',
#    'display_phone': '(718) 398-8181',
#    'distance': 2599.9679155852905},
#   {'id': 'xYDays-olVw50rdusxW5Rw',
#    'alias': 'wanpaku-brooklyn',
#    'name': 'Wanpaku',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fKWkpsQn7txEg_220UUZ3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wanpaku-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 77,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72355, 'longitude': -73.95092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '621 Manhattan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['621 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183833139',
#    'display_phone': '(718) 383-3139',
#    'distance': 3993.2426403402364},
#   {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#    'alias': 'okonomi-brooklyn',
#    'name': 'Okonomi',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 455,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '150 Ainslie St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3000.166602714201},
#   {'id': 'Neiw4AB_s7BpLSxyUrSXBQ',
#    'alias': 'sushi-and-noodles-brooklyn-13',
#    'name': 'Sushi & Noodles',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gyhk02Ro7acnmoVYxBNXwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sushi-and-noodles-brooklyn-13?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 141,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70347, 'longitude': -73.92577},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Troutman St',
#     'address2': None,
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Troutman St', 'Brooklyn, NY 11237']},
#    'phone': '+17183662825',
#    'display_phone': '(718) 366-2825',
#    'distance': 952.3481408101222},
#   {'id': '-fRgp3gv0-R6y9YOJX8ZVA',
#    'alias': 'warude-brooklyn',
#    'name': 'Warude',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/73_WgakzKOr2t4xjDE7__Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/warude-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 65,
#    'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6846262, 'longitude': -73.9440354},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '385 Tompkins Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['385 Tompkins Ave', 'Brooklyn, NY 11216']},
#    'phone': '+17186844449',
#    'display_phone': '(718) 684-4449',
#    'distance': 2282.1465318323735},
#   {'id': 'YwpP-mgXV5N35xhLibLw5g',
#    'alias': 'mos-original-brooklyn',
#    'name': "Mo's Original",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SsVjlE0y0p1ghVHLL2gJOg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mos-original-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 86,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.66127, 'longitude': -73.95342},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '453 Rogers Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['453 Rogers Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17185130698',
#    'display_phone': '(718) 513-0698',
#    'distance': 4680.352902485553},
#   {'id': 'ZaJS8EKQNSaQpwpmgN-vVw',
#    'alias': 'samurai-mama-brooklyn',
#    'name': 'Samurai Mama',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU4mCy9pszj-Kx3WzcAXQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/samurai-mama-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 592,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7140208838114,
#     'longitude': -73.960325717926},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '205 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17185996161',
#    'display_phone': '(718) 599-6161',
#    'distance': 3884.61133831763},
#   {'id': 'iYFauSnqLxvr4HTY_cIElg',
#    'alias': 'little-mo-brooklyn',
#    'name': 'Little Mo',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f2pS7K-QYKqA97dr9cBmVg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/little-mo-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 317,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69701, 'longitude': -73.93368},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1158 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1158 Myrtle Ave', 'Brooklyn, NY 11221']},
#    'phone': '+19292108100',
#    'display_phone': '(929) 210-8100',
#    'distance': 1066.5583968943095},
#   {'id': 'ZrzSDDj54aUlPqn4MQMKeQ',
#    'alias': 'momo-sushi-shack-brooklyn',
#    'name': 'Momo Sushi Shack',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZfIEda7Sh5fXBxbrTm9fw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/momo-sushi-shack-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 658,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7051406133, 'longitude': -73.933340055132},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '43 Bogart St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['43 Bogart St', 'Brooklyn, NY 11206']},
#    'phone': '+17184186666',
#    'display_phone': '(718) 418-6666',
#    'distance': 1475.7293427113775},
#   {'id': 'TZG0qTIGdeOtCkBrSU6v0Q',
#    'alias': 'minami-lounge-brooklyn',
#    'name': 'Minami Lounge',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bDECpLa89adXlMWDv1bK3w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/minami-lounge-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 47,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'lounges', 'title': 'Lounges'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70944, 'longitude': -73.95566},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '299 S 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['299 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+19179091896',
#    'display_phone': '(917) 909-1896',
#    'distance': 3283.8083086877627},
#   {'id': '74SKT4IxG-hXz71nRbheng',
#    'alias': 'ozi-dumplings-brooklyn-2',
#    'name': 'Ozi Dumplings',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/glLLmQO-W-5RLuaXu8iz4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ozi-dumplings-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 129,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70381, 'longitude': -73.933159},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '19 Bogart St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Bogart St', 'Brooklyn, NY 11206']},
#    'phone': '+17189136316',
#    'display_phone': '(718) 913-6316',
#    'distance': 1369.0906097136237},
#   {'id': 'NEK3UUNhh5YLhxfrjDu2Og',
#    'alias': 'darlings-brooklyn',
#    'name': 'Darlings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mDAfY2zXQWR3eTdq8Ymatw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/darlings-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 24,
#    'categories': [{'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.699996, 'longitude': -73.9197525},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '242 Himrod St',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 Himrod St', 'Brooklyn, NY 11237']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 502.66236037888024},
#   {'id': 'KfFXfxN6qzk_dTcQjsK-OQ',
#    'alias': 'fukuyama-sushi-and-ramen-brooklyn-2',
#    'name': 'Fukuyama Sushi & Ramen',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j-z7MkTDUokBhAJo84YxoA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fukuyama-sushi-and-ramen-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 43,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.713916, 'longitude': -73.948283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '622 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['622 Metropolitan Ave', 'Brooklyn, NY 11211']},
#    'phone': '+17187821496',
#    'display_phone': '(718) 782-1496',
#    'distance': 3066.164008122554},
#   {'id': 'EG8MnctXEOXkm7b_yge7Pw',
#    'alias': 'osakana-brooklyn',
#    'name': 'Osakana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/shWR3yKyQpGlAyzlwHoAwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osakana-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 47,
#    'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#     {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71224, 'longitude': -73.94376},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '290 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['290 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+16466534633',
#    'display_phone': '(646) 653-4633',
#    'distance': 2659.2048959044128},
#   {'id': '7USePx0k_ENmwrw625X9kA',
#    'alias': 'jin-ramen-sushi-ridgewood',
#    'name': 'Jin Ramen Sushi',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rMJCqL0M15BXTGvgMOyOPQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jin-ramen-sushi-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 80,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70772, 'longitude': -73.89722},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '66-41 Fresh Pond Rd',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66-41 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+13479873959',
#    'display_phone': '(347) 987-3959',
#    'distance': 2424.2730761546527},
#   {'id': 'e_hmhxJbpSPAGEfim86PVQ',
#    'alias': 'gentle-perch-brooklyn',
#    'name': 'Gentle Perch',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6NjW0WpkopEaJydy_MqnYw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gentle-perch-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 66,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.705106, 'longitude': -73.942587},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '112 Graham Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+19292980041',
#    'display_phone': '(929) 298-0041',
#    'distance': 2093.8081161131995},
#   {'id': '3gqKLANaXNsHZnPDjKrcTg',
#    'alias': 'win-son-brooklyn-4',
#    'name': 'Win Son',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EXCnl7qaa1wEQMWMI6ZqRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/win-son-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 484,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70747, 'longitude': -73.94339},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '159 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['159 Graham Ave', 'Brooklyn, NY 11206']},
#    'phone': '+13474576010',
#    'display_phone': '(347) 457-6010',
#    'distance': 2297.6593167539736},
#   {'id': 'VF3Ep2NQN8FqSCV8ySulSA',
#    'alias': '19-cafe-new-york',
#    'name': '19 Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mesyWl6-K3LzifhKEwcRdQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/19-cafe-new-york?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 105,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70515, 'longitude': -73.9444199},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '84 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '11206',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 Manhattan Ave', 'New York, NY 11206']},
#    'phone': '+17183878777',
#    'display_phone': '(718) 387-8777',
#    'distance': 2229.1185954195703},
#   {'id': 'H5jHfG4ZkNPaG6vojmAXww',
#    'alias': 'chingoo-restaurant-brooklyn',
#    'name': 'Chingoo Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGLcBaBHhGBFC5u1BRNfhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chingoo-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 34,
#    'categories': [{'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.715796, 'longitude': -73.944733},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '373 Graham Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['373 Graham Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13479161269',
#    'display_phone': '(347) 916-1269',
#    'distance': 2997.924651025122},
#   {'id': '6wJOojpF2c4lLeBNbTBB0A',
#    'alias': 'baoburg-brooklyn-2',
#    'name': 'Baoburg',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvXZWKSplu8HEMDwM8waog/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/baoburg-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 214,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'panasian', 'title': 'Pan Asian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7234929271998,
#     'longitude': -73.9503321851175},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '614 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['614 Manhattan Ave', 'Brooklyn, NY 11222']},
#    'phone': '+17183490011',
#    'display_phone': '(718) 349-0011',
#    'distance': 3957.3383811607714},
#   {'id': 'NCnOkzbyfzDltnBnJySfzw',
#    'alias': 'amami-bar-and-restaurant-brooklyn',
#    'name': 'Amami Bar and Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzSSNiTIcoEWoRm3fQphtA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amami-bar-and-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 142,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.723548, 'longitude': -73.952194},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '57 Nassau Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11222',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['57 Nassau Ave', 'Brooklyn, NY 11222']},
#    'phone': '+19179091568',
#    'display_phone': '(917) 909-1568',
#    'distance': 4057.6647035585934},
#   {'id': 'IoAUbSudW1Mds5_XY_01Rg',
#    'alias': 'mission-chinese-food-brooklyn',
#    'name': 'Mission Chinese Food',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UB19gADyJHsF9M7yrnTCtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mission-chinese-food-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 74,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.70933, 'longitude': -73.92315},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '599 Johnson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['599 Johnson Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17186283731',
#    'display_phone': '(718) 628-3731',
#    'distance': 1536.9682941592007},
#   {'id': 'BlzlywklvYdek5uk_NCX9g',
#    'alias': 'suzume-brooklyn',
#    'name': 'Suzume',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJ6jgbfh1BIofEAz2ztaCg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/suzume-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 301,
#    'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#     {'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7131652, 'longitude': -73.9494479},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '545 Lorimer St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['545 Lorimer St', 'Brooklyn, NY 11211']},
#    'phone': '+17184860200',
#    'display_phone': '(718) 486-0200',
#    'distance': 3081.685928676039},
#   {'id': 'eBljpfHpo3m6oc5SFw-mLw',
#    'alias': 'falansai-brooklyn-2',
#    'name': 'Falansai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RxOKUavhfM8Ap8iYmgCQuQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/falansai-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 216,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70676, 'longitude': -73.92877},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '112 Harrison Pl',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['112 Harrison Pl', 'Brooklyn, NY 11237']},
#    'phone': '+13475991190',
#    'display_phone': '(347) 599-1190',
#    'distance': 1390.682726451697},
#   {'id': 'vmU2oLglodmiFK0iQGzDFw',
#    'alias': 'sally-roots-brooklyn',
#    'name': 'Sally Roots',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KvO6-IUnFcSO9I1kZFYwXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sally-roots-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 253,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.702756, 'longitude': -73.916372},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '195 Wyckoff Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['195 Wyckoff Ave', 'Brooklyn, NY 11237']},
#    'phone': '+13474250888',
#    'display_phone': '(347) 425-0888',
#    'distance': 892.0227449875638},
#   {'id': 'zJcxZQbTSAP3q4Fy-6WAyw',
#    'alias': 'shalom-japan-brooklyn',
#    'name': 'Shalom Japan',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RDRo2F_OQ0XtJEefYBqoFw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shalom-japan-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 275,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7091679, 'longitude': -73.9558028},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '310 S 4th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['310 S 4th St', 'Brooklyn, NY 11211']},
#    'phone': '+17183884012',
#    'display_phone': '(718) 388-4012',
#    'distance': 3286.364089590897},
#   {'id': 'FYWwW5lcxKzaA98Xgw8bqA',
#    'alias': 'hanon-brooklyn',
#    'name': 'hanon',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RQz8Yzxa66xQ07DxVgsgbQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hanon-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 103,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7134488, 'longitude': -73.9513445},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '436 Union Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['436 Union Ave', 'Brooklyn, NY 11211']},
#    'phone': '+13477991433',
#    'display_phone': '(347) 799-1433',
#    'distance': 3226.2627957803984},
#   {'id': 'EvLkJaWEXTZ8QNBrxOhDsA',
#    'alias': 'bunker-brooklyn',
#    'name': 'Bunker',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UoY5PqkIQ1vtQblao9t4zQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bunker-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 718,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7105638, 'longitude': -73.9233984},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '99 Scott Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11237',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 Scott Ave', 'Brooklyn, NY 11237']},
#    'phone': '+17183864282',
#    'display_phone': '(718) 386-4282',
#    'distance': 1674.0448342669256},
#   {'id': 'LHcpOjPtc8QQCrFiRFjWyA',
#    'alias': 'slow-loris-brooklyn',
#    'name': 'Slow Loris',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iIN136Y8pbolq2gdWtkcfA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/slow-loris-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 86,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.6601311, 'longitude': -73.9607934},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '556 Flatbush Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11225',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['556 Flatbush Ave', 'Brooklyn, NY 11225']},
#    'phone': '+17184847170',
#    'display_phone': '(718) 484-7170',
#    'distance': 5164.849281134537},
#   {'id': 'KrJ6m_TkxBAPPSNH-G7rvQ',
#    'alias': 'u-gu-brooklyn-4',
#    'name': 'U-gu',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/otCFJmUAou8b89de_Lo7SA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/u-gu-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 128,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'japanese', 'title': 'Japanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.69393, 'longitude': -73.96284},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '541 Myrtle Ave',
#     'address2': 'Ste B',
#     'address3': None,
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['541 Myrtle Ave', 'Ste B', 'Brooklyn, NY 11205']},
#    'phone': '+17188570222',
#    'display_phone': '(718) 857-0222',
#    'distance': 3517.2576174803976},
#   {'id': 'Op43gk4VHEhENJGs-FKi3g',
#    'alias': 'garlic-to-the-chicken-ridgewood',
#    'name': 'Garlic To the Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lX3v6JQXGNKyT9Y4c7BfCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/garlic-to-the-chicken-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 81,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7049523, 'longitude': -73.9022751},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '66-92 Forest Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['66-92 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+13476892670',
#    'display_phone': '(347) 689-2670',
#    'distance': 1901.6867809382948},
#   {'id': 'fHHpSKT9u7PQBYaMW5cEkA',
#    'alias': 'trad-room-brooklyn-2',
#    'name': 'Trad Room',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4eW608lQXYBaT7fDSLMpBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/trad-room-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 46,
#    'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68388, 'longitude': -73.92952},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '266 Malcolm X Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11233',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['266 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#    'phone': '+13472405760',
#    'display_phone': '(347) 240-5760',
#    'distance': 1482.353521722662},
#   {'id': '0zcgBHXbaJn0ZxgpcTJ1aQ',
#    'alias': 'nostrand-cafe-bedford-stuyvesant',
#    'name': 'Nostrand Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svDue-WeWJImXRsYNTvknQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nostrand-cafe-bedford-stuyvesant?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 105,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68978, 'longitude': -73.951142},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '261 Nostrand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Bedford-Stuyvesant',
#     'zip_code': '11216',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['261 Nostrand Ave', 'Bedford-Stuyvesant, NY 11216']},
#    'phone': '+17189758588',
#    'display_phone': '(718) 975-8588',
#    'distance': 2615.0332012479876},
#   {'id': '1m1iOc8EplJ4tiCez7hf2Q',
#    'alias': '750-myrtle-diner-brooklyn',
#    'name': '750 Myrtle Diner',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mMU65sTdliF8vLWy_DLArw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/750-myrtle-diner-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 114,
#    'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'izakaya', 'title': 'Izakaya'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.694779, 'longitude': -73.952807},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '750 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11205',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['750 Myrtle Ave', 'Brooklyn, NY 11205']},
#    'phone': '+17187585298',
#    'display_phone': '(718) 758-5298',
#    'distance': 2669.170419098156},
#   {'id': '30pqvzHrCNmnodJCRyzrTg',
#    'alias': 'snacky-brooklyn',
#    'name': 'Snacky',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3a3ihfFB5jp8AQTj_ouZJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/snacky-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 193,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.71439, 'longitude': -73.9607},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '187 Grand St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['187 Grand St', 'Brooklyn, NY 11211']},
#    'phone': '+17184864848',
#    'display_phone': '(718) 486-4848',
#    'distance': 3932.359000851308},
#   {'id': '98URsYAwTfXRPP5e1ONPug',
#    'alias': 'maya-bed-stuy-brooklyn-4',
#    'name': 'Maya Bed Stuy',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7hMQGWWcY2PTiHciQjAhrw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maya-bed-stuy-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#    'review_count': 89,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.68719, 'longitude': -73.944167},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '563 Gates Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11221',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['563 Gates Ave', 'Brooklyn, NY 11221']},
#    'phone': '+13473266003',
#    'display_phone': '(347) 326-6003',
#    'distance': 2155.4898321203373}],
#  'total': 132,
#  'region': {'center': {'longitude': -73.9211654663086,
#    'latitude': 40.69560420717647}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
# your code here
for key in data:
    print(f"{key}\n {type(data[key])}")
# Out:
# businesses
#  <class 'list'>
# total
#  <class 'int'>
# region
#  <class 'dict'>

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 132

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
data['businesses']
# Out:
# [{'id': 'e-G1yC5u8LOcQ-fx0Lxthw',
#   'alias': 'ajihei-bushwick-brooklyn',
#   'name': 'Ajihei Bushwick',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7QCedXet5RI8rF0dxB2FHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 79,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70416, 'longitude': -73.92799},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '156 Knickerbocker Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['156 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17185522065',
#   'display_phone': '(718) 552-2065',
#   'distance': 1110.9503886333598},
#  {'id': 'G4qZvheX74VwYvek7I8iQg',
#   'alias': 'buntopia-brooklyn',
#   'name': 'Buntopia',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/mL7sje7bFV_79mg4pJK8eA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buntopia-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 290,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69598, 'longitude': -73.93398},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '994 Broadway',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['994 Broadway', 'Brooklyn, NY 11221']},
#   'phone': '+13474353660',
#   'display_phone': '(347) 435-3660',
#   'distance': 1081.5446435111458},
#  {'id': 'JRmQRFEEnSUdAcesHun9AQ',
#   'alias': 'ichiran-brooklyn-brooklyn',
#   'name': 'ICHIRAN - Brooklyn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wDXO7-SIqQUOn6B8apTVvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ichiran-brooklyn-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 1130,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.707587, 'longitude': -73.933271},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '374 Johnson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['374 Johnson Ave', 'Brooklyn, NY 11206']},
#   'phone': '+17183810491',
#   'display_phone': '(718) 381-0491',
#   'distance': 1678.3123837525588},
#  {'id': '7xpbioe88rnW7JjzLEQeRg',
#   'alias': 'samurai-papa-brooklyn-2',
#   'name': 'Samurai Papa',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/H9YugRMONrxKBkAFx_6yPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/samurai-papa-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 269,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.702892072912, 'longitude': -73.943588398397},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '32 Varet St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['32 Varet St', 'Brooklyn, NY 11206']},
#   'phone': '+17185997171',
#   'display_phone': '(718) 599-7171',
#   'distance': 2056.670242790492},
#  {'id': 'nhez4xxvwwYIQEN2Vrj9mQ',
#   'alias': 'yuji-ramen-brooklyn-3',
#   'name': 'YUJI Ramen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BSnln7Ugk-eS6K21vN1vrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yuji-ramen-brooklyn-3?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 130,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.712527, 'longitude': -73.9487788},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '150 Ainslie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2993.1558549969072},
#  {'id': 'hdiTkEnD14VpXNl-APTg2g',
#   'alias': 'nana-ramen-brooklyn',
#   'name': 'Nana Ramen',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LXLGS9Go-Fh20inuHsxzsg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nana-ramen-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 154,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6815479, 'longitude': -73.9289913},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '330 Malcolm X Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11233',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['330 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#   'phone': '+19292100589',
#   'display_phone': '(929) 210-0589',
#   'distance': 1696.5598909463495},
#  {'id': 'ujozQCThEuSfEXi5_6ZTPQ',
#   'alias': 'ramen-setagaya-brooklyn',
#   'name': 'Ramen Setagaya',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/QzLlGf3cgJMSpXGMqShDDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-setagaya-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 260,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7147999, 'longitude': -73.96115},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '280 Bedford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['280 Bedford Ave', 'Brooklyn, NY 11249']},
#   'phone': '+17182188508',
#   'display_phone': '(718) 218-8508',
#   'distance': 3995.0476710927433},
#  {'id': '0gPXct_l_82phIEoKdtWZw',
#   'alias': 'ryujin-brooklyn-8',
#   'name': 'RYUJIN',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qok9QqxbVYHMHETgZ2gs9w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ryujin-brooklyn-8?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 267,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.711178187852, 'longitude': -73.9506256676857},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '513 Grand St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['513 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17187099888',
#   'display_phone': '(718) 709-9888',
#   'distance': 3027.565012617573},
#  {'id': 'GBk_i2qnjMtQIt_ntJpzbw',
#   'alias': 'ramen-andante-brooklyn-2',
#   'name': 'Ramen Andante',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eVeSjIIG5gXuZ6nAknFK_A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-andante-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 59,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7148695, 'longitude': -73.9625803},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '130 Grand St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11249',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['130 Grand St', 'Brooklyn, NY 11249']},
#   'phone': '+19293970010',
#   'display_phone': '(929) 397-0010',
#   'distance': 4099.873518167904},
#  {'id': 'qd9_gxrmskbOT6OLN9sShA',
#   'alias': 'dock-asian-eatery-brooklyn-4',
#   'name': 'Dock Asian Eatery',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hG7_CwCjCuUW8IrbOOA6ng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/dock-asian-eatery-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 129,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70628, 'longitude': -73.92274},
#   'transactions': ['restaurant_reservation', 'delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '22 Wyckoff Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['22 Wyckoff Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17188213900',
#   'display_phone': '(718) 821-3900',
#   'distance': 1194.4902218404427},
#  {'id': 'v3qQvMjj4KSZ4dPU4ERyiw',
#   'alias': 'ramen-spot-brooklyn-4',
#   'name': 'Ramen Spot',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/xj3ctOgKFjIwEACzDS6W6g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ramen-spot-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 85,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7268634, 'longitude': -73.952345},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '760 Manhattan Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['760 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17188092527',
#   'display_phone': '(718) 809-2527',
#   'distance': 4357.526523004717},
#  {'id': 'eS9mTLlWwu_Ap2ROMQWPxg',
#   'alias': 'chuko-brooklyn-2',
#   'name': 'Chuko',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MD7Q6u1eUGzEDBtr6Qyimw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chuko-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 1064,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.680784, 'longitude': -73.967455},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '565 Vanderbilt Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11238',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['565 Vanderbilt Ave', 'Brooklyn, NY 11238']},
#   'phone': '+13474259570',
#   'display_phone': '(347) 425-9570',
#   'distance': 4236.568327876994},
#  {'id': 'IuMvrvXTTZm4NQYO1O1dbg',
#   'alias': 'kuma-nyc-brooklyn-2',
#   'name': 'Kuma NYC',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aRGL9irXCX7SojclW2Libw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kuma-nyc-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 46,
#   'categories': [{'alias': 'poke', 'title': 'Poke'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.699183, 'longitude': -73.91304},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1520 Myrtle Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1520 Myrtle Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17183663790',
#   'display_phone': '(718) 366-3790',
#   'distance': 791.767731756538},
#  {'id': 'ooHTw6KGNXsKj5TmyHKVuQ',
#   'alias': 'lucys-vietnamese-bushwick-bushwick',
#   'name': "Lucy's Vietnamese Bushwick",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/d842GjU-5cUshM3opPmEMw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lucys-vietnamese-bushwick-bushwick?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 470,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.699661, 'longitude': -73.916012},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '262 Irving Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bushwick',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['262 Irving Ave', 'Bushwick, NY 11237']},
#   'phone': '+13472401599',
#   'display_phone': '(347) 240-1599',
#   'distance': 633.2413911641898},
#  {'id': 'Dv28TvKBh_8i6W02uAaMKw',
#   'alias': 'samurai-papa-bs-brooklyn',
#   'name': 'Samurai Papa BS',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKpVaDY0ppHibH2R0BbFLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/samurai-papa-bs-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 153,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.68981, 'longitude': -73.95101},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '594 Lafayette Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['594 Lafayette Ave', 'Brooklyn, NY 11216']},
#   'phone': '+17183988181',
#   'display_phone': '(718) 398-8181',
#   'distance': 2599.9679155852905},
#  {'id': 'xYDays-olVw50rdusxW5Rw',
#   'alias': 'wanpaku-brooklyn',
#   'name': 'Wanpaku',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/fKWkpsQn7txEg_220UUZ3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wanpaku-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 77,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'japacurry', 'title': 'Japanese Curry'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.72355, 'longitude': -73.95092},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '621 Manhattan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['621 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17183833139',
#   'display_phone': '(718) 383-3139',
#   'distance': 3993.2426403402364},
#  {'id': '7OMGEtFWT6sdd9TVuoGqJQ',
#   'alias': 'okonomi-brooklyn',
#   'name': 'Okonomi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RMSBnhoB5aHc-3CUSwULgg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/okonomi-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 455,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.712622, 'longitude': -73.9487843},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '150 Ainslie St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['150 Ainslie St', 'Brooklyn, NY 11211']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3000.166602714201},
#  {'id': 'Neiw4AB_s7BpLSxyUrSXBQ',
#   'alias': 'sushi-and-noodles-brooklyn-13',
#   'name': 'Sushi & Noodles',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Gyhk02Ro7acnmoVYxBNXwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-and-noodles-brooklyn-13?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 141,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70347, 'longitude': -73.92577},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '274 Troutman St',
#    'address2': None,
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['274 Troutman St', 'Brooklyn, NY 11237']},
#   'phone': '+17183662825',
#   'display_phone': '(718) 366-2825',
#   'distance': 952.3481408101222},
#  {'id': '-fRgp3gv0-R6y9YOJX8ZVA',
#   'alias': 'warude-brooklyn',
#   'name': 'Warude',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/73_WgakzKOr2t4xjDE7__Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/warude-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 65,
#   'categories': [{'alias': 'tacos', 'title': 'Tacos'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6846262, 'longitude': -73.9440354},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '385 Tompkins Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['385 Tompkins Ave', 'Brooklyn, NY 11216']},
#   'phone': '+17186844449',
#   'display_phone': '(718) 684-4449',
#   'distance': 2282.1465318323735},
#  {'id': 'YwpP-mgXV5N35xhLibLw5g',
#   'alias': 'mos-original-brooklyn',
#   'name': "Mo's Original",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SsVjlE0y0p1ghVHLL2gJOg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mos-original-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 86,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'bbq', 'title': 'Barbeque'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.66127, 'longitude': -73.95342},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '453 Rogers Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11225',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['453 Rogers Ave', 'Brooklyn, NY 11225']},
#   'phone': '+17185130698',
#   'display_phone': '(718) 513-0698',
#   'distance': 4680.352902485553},
#  {'id': 'ZaJS8EKQNSaQpwpmgN-vVw',
#   'alias': 'samurai-mama-brooklyn',
#   'name': 'Samurai Mama',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iU4mCy9pszj-Kx3WzcAXQw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/samurai-mama-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 592,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7140208838114, 'longitude': -73.960325717926},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '205 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['205 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17185996161',
#   'display_phone': '(718) 599-6161',
#   'distance': 3884.61133831763},
#  {'id': 'iYFauSnqLxvr4HTY_cIElg',
#   'alias': 'little-mo-brooklyn',
#   'name': 'Little Mo',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f2pS7K-QYKqA97dr9cBmVg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/little-mo-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 317,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.69701, 'longitude': -73.93368},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1158 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['1158 Myrtle Ave', 'Brooklyn, NY 11221']},
#   'phone': '+19292108100',
#   'display_phone': '(929) 210-8100',
#   'distance': 1066.5583968943095},
#  {'id': 'ZrzSDDj54aUlPqn4MQMKeQ',
#   'alias': 'momo-sushi-shack-brooklyn',
#   'name': 'Momo Sushi Shack',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/eZfIEda7Sh5fXBxbrTm9fw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/momo-sushi-shack-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 658,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7051406133, 'longitude': -73.933340055132},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '43 Bogart St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['43 Bogart St', 'Brooklyn, NY 11206']},
#   'phone': '+17184186666',
#   'display_phone': '(718) 418-6666',
#   'distance': 1475.7293427113775},
#  {'id': 'TZG0qTIGdeOtCkBrSU6v0Q',
#   'alias': 'minami-lounge-brooklyn',
#   'name': 'Minami Lounge',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bDECpLa89adXlMWDv1bK3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/minami-lounge-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 47,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70944, 'longitude': -73.95566},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '299 S 4th St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['299 S 4th St', 'Brooklyn, NY 11211']},
#   'phone': '+19179091896',
#   'display_phone': '(917) 909-1896',
#   'distance': 3283.8083086877627},
#  {'id': '74SKT4IxG-hXz71nRbheng',
#   'alias': 'ozi-dumplings-brooklyn-2',
#   'name': 'Ozi Dumplings',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/glLLmQO-W-5RLuaXu8iz4g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ozi-dumplings-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 129,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70381, 'longitude': -73.933159},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '19 Bogart St',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['19 Bogart St', 'Brooklyn, NY 11206']},
#   'phone': '+17189136316',
#   'display_phone': '(718) 913-6316',
#   'distance': 1369.0906097136237},
#  {'id': 'NEK3UUNhh5YLhxfrjDu2Og',
#   'alias': 'darlings-brooklyn',
#   'name': 'Darlings',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mDAfY2zXQWR3eTdq8Ymatw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/darlings-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 24,
#   'categories': [{'alias': 'bars', 'title': 'Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.699996, 'longitude': -73.9197525},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '242 Himrod St',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['242 Himrod St', 'Brooklyn, NY 11237']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 502.66236037888024},
#  {'id': 'KfFXfxN6qzk_dTcQjsK-OQ',
#   'alias': 'fukuyama-sushi-and-ramen-brooklyn-2',
#   'name': 'Fukuyama Sushi & Ramen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/j-z7MkTDUokBhAJo84YxoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fukuyama-sushi-and-ramen-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 43,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'ramen', 'title': 'Ramen'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.713916, 'longitude': -73.948283},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '622 Metropolitan Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['622 Metropolitan Ave', 'Brooklyn, NY 11211']},
#   'phone': '+17187821496',
#   'display_phone': '(718) 782-1496',
#   'distance': 3066.164008122554},
#  {'id': 'EG8MnctXEOXkm7b_yge7Pw',
#   'alias': 'osakana-brooklyn',
#   'name': 'Osakana',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/shWR3yKyQpGlAyzlwHoAwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/osakana-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 47,
#   'categories': [{'alias': 'seafoodmarkets', 'title': 'Seafood Markets'},
#    {'alias': 'cookingschools', 'title': 'Cooking Schools'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71224, 'longitude': -73.94376},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '290 Graham Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['290 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+16466534633',
#   'display_phone': '(646) 653-4633',
#   'distance': 2659.2048959044128},
#  {'id': '7USePx0k_ENmwrw625X9kA',
#   'alias': 'jin-ramen-sushi-ridgewood',
#   'name': 'Jin Ramen Sushi',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rMJCqL0M15BXTGvgMOyOPQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jin-ramen-sushi-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 80,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.70772, 'longitude': -73.89722},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '66-41 Fresh Pond Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Ridgewood',
#    'zip_code': '11385',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['66-41 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#   'phone': '+13479873959',
#   'display_phone': '(347) 987-3959',
#   'distance': 2424.2730761546527},
#  {'id': 'e_hmhxJbpSPAGEfim86PVQ',
#   'alias': 'gentle-perch-brooklyn',
#   'name': 'Gentle Perch',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6NjW0WpkopEaJydy_MqnYw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gentle-perch-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 66,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.705106, 'longitude': -73.942587},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '112 Graham Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['112 Graham Ave', 'Brooklyn, NY 11206']},
#   'phone': '+19292980041',
#   'display_phone': '(929) 298-0041',
#   'distance': 2093.8081161131995},
#  {'id': '3gqKLANaXNsHZnPDjKrcTg',
#   'alias': 'win-son-brooklyn-4',
#   'name': 'Win Son',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/EXCnl7qaa1wEQMWMI6ZqRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/win-son-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 484,
#   'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70747, 'longitude': -73.94339},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '159 Graham Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['159 Graham Ave', 'Brooklyn, NY 11206']},
#   'phone': '+13474576010',
#   'display_phone': '(347) 457-6010',
#   'distance': 2297.6593167539736},
#  {'id': 'VF3Ep2NQN8FqSCV8ySulSA',
#   'alias': '19-cafe-new-york',
#   'name': '19 Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mesyWl6-K3LzifhKEwcRdQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/19-cafe-new-york?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 105,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.70515, 'longitude': -73.9444199},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '84 Manhattan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'New York',
#    'zip_code': '11206',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['84 Manhattan Ave', 'New York, NY 11206']},
#   'phone': '+17183878777',
#   'display_phone': '(718) 387-8777',
#   'distance': 2229.1185954195703},
#  {'id': 'H5jHfG4ZkNPaG6vojmAXww',
#   'alias': 'chingoo-restaurant-brooklyn',
#   'name': 'Chingoo Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lGLcBaBHhGBFC5u1BRNfhA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chingoo-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 34,
#   'categories': [{'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.715796, 'longitude': -73.944733},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '373 Graham Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['373 Graham Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13479161269',
#   'display_phone': '(347) 916-1269',
#   'distance': 2997.924651025122},
#  {'id': '6wJOojpF2c4lLeBNbTBB0A',
#   'alias': 'baoburg-brooklyn-2',
#   'name': 'Baoburg',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AvXZWKSplu8HEMDwM8waog/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/baoburg-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 214,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'panasian', 'title': 'Pan Asian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7234929271998,
#    'longitude': -73.9503321851175},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '614 Manhattan Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['614 Manhattan Ave', 'Brooklyn, NY 11222']},
#   'phone': '+17183490011',
#   'display_phone': '(718) 349-0011',
#   'distance': 3957.3383811607714},
#  {'id': 'NCnOkzbyfzDltnBnJySfzw',
#   'alias': 'amami-bar-and-restaurant-brooklyn',
#   'name': 'Amami Bar and Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/MzSSNiTIcoEWoRm3fQphtA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/amami-bar-and-restaurant-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 142,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.723548, 'longitude': -73.952194},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '57 Nassau Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11222',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['57 Nassau Ave', 'Brooklyn, NY 11222']},
#   'phone': '+19179091568',
#   'display_phone': '(917) 909-1568',
#   'distance': 4057.6647035585934},
#  {'id': 'IoAUbSudW1Mds5_XY_01Rg',
#   'alias': 'mission-chinese-food-brooklyn',
#   'name': 'Mission Chinese Food',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UB19gADyJHsF9M7yrnTCtQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mission-chinese-food-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 74,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.70933, 'longitude': -73.92315},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '599 Johnson Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['599 Johnson Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17186283731',
#   'display_phone': '(718) 628-3731',
#   'distance': 1536.9682941592007},
#  {'id': 'BlzlywklvYdek5uk_NCX9g',
#   'alias': 'suzume-brooklyn',
#   'name': 'Suzume',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dJ6jgbfh1BIofEAz2ztaCg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/suzume-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 301,
#   'categories': [{'alias': 'filipino', 'title': 'Filipino'},
#    {'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7131652, 'longitude': -73.9494479},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '545 Lorimer St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['545 Lorimer St', 'Brooklyn, NY 11211']},
#   'phone': '+17184860200',
#   'display_phone': '(718) 486-0200',
#   'distance': 3081.685928676039},
#  {'id': 'eBljpfHpo3m6oc5SFw-mLw',
#   'alias': 'falansai-brooklyn-2',
#   'name': 'Falansai',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RxOKUavhfM8Ap8iYmgCQuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/falansai-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 216,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.70676, 'longitude': -73.92877},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '112 Harrison Pl',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['112 Harrison Pl', 'Brooklyn, NY 11237']},
#   'phone': '+13475991190',
#   'display_phone': '(347) 599-1190',
#   'distance': 1390.682726451697},
#  {'id': 'vmU2oLglodmiFK0iQGzDFw',
#   'alias': 'sally-roots-brooklyn',
#   'name': 'Sally Roots',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KvO6-IUnFcSO9I1kZFYwXg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sally-roots-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 253,
#   'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.702756, 'longitude': -73.916372},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '195 Wyckoff Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['195 Wyckoff Ave', 'Brooklyn, NY 11237']},
#   'phone': '+13474250888',
#   'display_phone': '(347) 425-0888',
#   'distance': 892.0227449875638},
#  {'id': 'zJcxZQbTSAP3q4Fy-6WAyw',
#   'alias': 'shalom-japan-brooklyn',
#   'name': 'Shalom Japan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RDRo2F_OQ0XtJEefYBqoFw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/shalom-japan-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 275,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7091679, 'longitude': -73.9558028},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$$',
#   'location': {'address1': '310 S 4th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['310 S 4th St', 'Brooklyn, NY 11211']},
#   'phone': '+17183884012',
#   'display_phone': '(718) 388-4012',
#   'distance': 3286.364089590897},
#  {'id': 'FYWwW5lcxKzaA98Xgw8bqA',
#   'alias': 'hanon-brooklyn',
#   'name': 'hanon',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/RQz8Yzxa66xQ07DxVgsgbQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hanon-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 103,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.7134488, 'longitude': -73.9513445},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '436 Union Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['436 Union Ave', 'Brooklyn, NY 11211']},
#   'phone': '+13477991433',
#   'display_phone': '(347) 799-1433',
#   'distance': 3226.2627957803984},
#  {'id': 'EvLkJaWEXTZ8QNBrxOhDsA',
#   'alias': 'bunker-brooklyn',
#   'name': 'Bunker',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UoY5PqkIQ1vtQblao9t4zQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bunker-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 718,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7105638, 'longitude': -73.9233984},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '99 Scott Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11237',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['99 Scott Ave', 'Brooklyn, NY 11237']},
#   'phone': '+17183864282',
#   'display_phone': '(718) 386-4282',
#   'distance': 1674.0448342669256},
#  {'id': 'LHcpOjPtc8QQCrFiRFjWyA',
#   'alias': 'slow-loris-brooklyn',
#   'name': 'Slow Loris',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iIN136Y8pbolq2gdWtkcfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/slow-loris-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 86,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.6601311, 'longitude': -73.9607934},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '556 Flatbush Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11225',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['556 Flatbush Ave', 'Brooklyn, NY 11225']},
#   'phone': '+17184847170',
#   'display_phone': '(718) 484-7170',
#   'distance': 5164.849281134537},
#  {'id': 'KrJ6m_TkxBAPPSNH-G7rvQ',
#   'alias': 'u-gu-brooklyn-4',
#   'name': 'U-gu',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/otCFJmUAou8b89de_Lo7SA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/u-gu-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 128,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.69393, 'longitude': -73.96284},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '541 Myrtle Ave',
#    'address2': 'Ste B',
#    'address3': None,
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['541 Myrtle Ave', 'Ste B', 'Brooklyn, NY 11205']},
#   'phone': '+17188570222',
#   'display_phone': '(718) 857-0222',
#   'distance': 3517.2576174803976},
#  {'id': 'Op43gk4VHEhENJGs-FKi3g',
#   'alias': 'garlic-to-the-chicken-ridgewood',
#   'name': 'Garlic To the Chicken',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/lX3v6JQXGNKyT9Y4c7BfCA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/garlic-to-the-chicken-ridgewood?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 81,
#   'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.7049523, 'longitude': -73.9022751},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '66-92 Forest Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Ridgewood',
#    'zip_code': '11385',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['66-92 Forest Ave', 'Ridgewood, NY 11385']},
#   'phone': '+13476892670',
#   'display_phone': '(347) 689-2670',
#   'distance': 1901.6867809382948},
#  {'id': 'fHHpSKT9u7PQBYaMW5cEkA',
#   'alias': 'trad-room-brooklyn-2',
#   'name': 'Trad Room',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4eW608lQXYBaT7fDSLMpBg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trad-room-brooklyn-2?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 46,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.68388, 'longitude': -73.92952},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '266 Malcolm X Blvd',
#    'address2': None,
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11233',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['266 Malcolm X Blvd', 'Brooklyn, NY 11233']},
#   'phone': '+13472405760',
#   'display_phone': '(347) 240-5760',
#   'distance': 1482.353521722662},
#  {'id': '0zcgBHXbaJn0ZxgpcTJ1aQ',
#   'alias': 'nostrand-cafe-bedford-stuyvesant',
#   'name': 'Nostrand Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/svDue-WeWJImXRsYNTvknQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nostrand-cafe-bedford-stuyvesant?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 105,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.68978, 'longitude': -73.951142},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '261 Nostrand Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Bedford-Stuyvesant',
#    'zip_code': '11216',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['261 Nostrand Ave', 'Bedford-Stuyvesant, NY 11216']},
#   'phone': '+17189758588',
#   'display_phone': '(718) 975-8588',
#   'distance': 2615.0332012479876},
#  {'id': '1m1iOc8EplJ4tiCez7hf2Q',
#   'alias': '750-myrtle-diner-brooklyn',
#   'name': '750 Myrtle Diner',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mMU65sTdliF8vLWy_DLArw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/750-myrtle-diner-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 114,
#   'categories': [{'alias': 'tapas', 'title': 'Tapas Bars'},
#    {'alias': 'izakaya', 'title': 'Izakaya'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.694779, 'longitude': -73.952807},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '750 Myrtle Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11205',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['750 Myrtle Ave', 'Brooklyn, NY 11205']},
#   'phone': '+17187585298',
#   'display_phone': '(718) 758-5298',
#   'distance': 2669.170419098156},
#  {'id': '30pqvzHrCNmnodJCRyzrTg',
#   'alias': 'snacky-brooklyn',
#   'name': 'Snacky',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3a3ihfFB5jp8AQTj_ouZJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/snacky-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 193,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'korean', 'title': 'Korean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.71439, 'longitude': -73.9607},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '187 Grand St',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11211',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['187 Grand St', 'Brooklyn, NY 11211']},
#   'phone': '+17184864848',
#   'display_phone': '(718) 486-4848',
#   'distance': 3932.359000851308},
#  {'id': '98URsYAwTfXRPP5e1ONPug',
#   'alias': 'maya-bed-stuy-brooklyn-4',
#   'name': 'Maya Bed Stuy',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7hMQGWWcY2PTiHciQjAhrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/maya-bed-stuy-brooklyn-4?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#   'review_count': 89,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.68719, 'longitude': -73.944167},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '563 Gates Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Brooklyn',
#    'zip_code': '11221',
#    'country': 'US',
#    'state': 'NY',
#    'display_address': ['563 Gates Ave', 'Brooklyn, NY 11221']},
#   'phone': '+13473266003',
#   'display_phone': '(347) 326-6003',
#   'distance': 2155.4898321203373}]

# %%
business
# Out:
# {'id': 'e-G1yC5u8LOcQ-fx0Lxthw',
#  'alias': 'ajihei-bushwick-brooklyn',
#  'name': 'Ajihei Bushwick',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7QCedXet5RI8rF0dxB2FHA/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/ajihei-bushwick-brooklyn?adjust_creative=8a3plc0HJl7r8T8PWdaSmg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8a3plc0HJl7r8T8PWdaSmg',
#  'review_count': 79,
#  'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#   {'alias': 'ramen', 'title': 'Ramen'},
#   {'alias': 'salad', 'title': 'Salad'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.70416, 'longitude': -73.92799},
#  'transactions': ['delivery', 'pickup'],
#  'price': '$$',
#  'location': {'address1': '156 Knickerbocker Ave',
#   'address2': None,
#   'address3': '',
#   'city': 'Brooklyn',
#   'zip_code': '11237',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['156 Knickerbocker Ave', 'Brooklyn, NY 11237']},
#  'phone': '+17185522065',
#  'display_phone': '(718) 552-2065',
#  'distance': 1110.9503886333598}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_list = (business['name'], 
            ', '.join(business['location']['display_address']), 
            len(business['price']),
           business['rating'])

# %%
biz_list
# Out:
# ('Ajihei Bushwick', '156 Knickerbocker Ave, Brooklyn, NY 11237', 2, 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    parsed_data = []
    
    # loop through our business and parse each individual business
    for business in list_of_data:
        print(business['name'])
        biz_list = [business['name'], 
            ', '.join(business['location']['display_address']), 
            business['price'],
                   business['rating']]
    # in the loop, add each individual parsed  business to our data container
        parsed_data.append(biz_list)

    # return the container with all of the parsed results
    return parsed_data

# %%
parsed_data = parse_data(data['businesses'])
# Out:
# Ajihei Bushwick
# Buntopia
# ICHIRAN - Brooklyn
# Samurai Papa
# YUJI Ramen
# Nana Ramen
# Ramen Setagaya
# RYUJIN
# Ramen Andante
# Dock Asian Eatery
# Ramen Spot
# Chuko
# Kuma NYC
# Lucy's Vietnamese Bushwick
# Samurai Papa BS
# Wanpaku
# Okonomi
# Sushi & Noodles
# Warude
# Mo's Original
# Samurai Mama
# Little Mo
# Momo Sushi Shack
# Minami Lounge
# Ozi Dumplings
# Darlings
# Fukuyama Sushi & Ramen
# Osakana
# Jin Ramen Sushi
# Gentle Perch
# Win Son
# 19 Cafe
# Chingoo Restaurant
# Baoburg
# Amami Bar and Restaurant
# Mission Chinese Food
# Suzume
# Falansai
# Sally Roots
# Shalom Japan
# hanon
# Bunker
# Slow Loris
# U-gu
# Garlic To the Chicken
# Trad Room
# Nostrand Cafe
# 750 Myrtle Diner
# Snacky
# Maya Bed Stuy

# %%
import pandas as pd

# %%
df = pd.DataFrame(parsed_data)

# %%
columns = ['Name', 'Address', 'Price']
df.columns = columns

# %%
df.head()
# Out:
#                  Name                                    Address Price
# 0     Ajihei Bushwick  156 Knickerbocker Ave, Brooklyn, NY 11237    $$
# 1            Buntopia           994 Broadway, Brooklyn, NY 11221    $$
# 2  ICHIRAN - Brooklyn        374 Johnson Ave, Brooklyn, NY 11206    $$
# 3        Samurai Papa            32 Varet St, Brooklyn, NY 11206    $$
# 4          YUJI Ramen         150 Ainslie St, Brooklyn, NY 11211    $$

# %%
df.to_csv('yelp_data.csv')
